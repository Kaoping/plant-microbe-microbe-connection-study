# %% [markdown]
# ### Climate variables along elevation

# %%
MAT_MAP_North = read.table(file = "MAT_MAP_North.txt", header =T)
head(MAT_MAP_North)
# Out:
#   elevation MAT_North MAP_North
# 1  600      11.083333 666
# 2  700      11.137500 666
# 3  800      10.279167 690
# 4  900      10.270833 693
# 5 1000       9.770833 714
# 6 1100       9.404166 728

# %%
summary(lm(MAT_North~elevation, data = MAT_MAP_North))
# Out:
# Call:
# lm(formula = MAT_North ~ elevation, data = MAT_MAP_North)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.36102 -0.11144  0.00637  0.07226  0.40743
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.365e+01  1.392e-01   98.06   <2e-16 ***
# elevation   -3.930e-03  8.717e-05  -45.08   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2081 on 17 degrees of freedom
# Multiple R-squared:  0.9917,	Adjusted R-squared:  0.9912
# F-statistic:  2032 on 1 and 17 DF,  p-value: < 2.2e-16

# %%
summary(lm(MAP_North~elevation, data = MAT_MAP_North))
# Out:
# Call:
# lm(formula = MAP_North ~ elevation, data = MAT_MAP_North)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.744  -8.093   1.112   8.184  13.488
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 6.194e+02  6.283e+00   98.58  < 2e-16 ***
# elevation   9.197e-02  3.935e-03   23.37 2.31e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.394 on 17 degrees of freedom
# Multiple R-squared:  0.9698,	Adjusted R-squared:  0.968
# F-statistic: 546.3 on 1 and 17 DF,  p-value: 2.31e-14

# %%
library(ggplot2)

ggplot(MAT_MAP_North, aes(x = elevation, y = MAT_North)) +
  geom_point() +
  geom_smooth(method = "lm", color = "black", se = FALSE) +
  labs(x = "Elevation(m)" , y = "Mean Annual Temperature (°C)" ) +
  theme_bw()

ggplot(MAT_MAP_North, aes(x = elevation, y = MAP_North)) +
  geom_point() +
  geom_smooth(method = "lm", color = "black", se = FALSE) +
  labs(x = "Elevation(m)" , y = "Mean Annual Precipitation (mm)" ) +
  theme_bw()
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ### rhizosphere fungal alpha diversity along elevation

# %%
North_alpha = read.table(file = "North_alpha.txt", header = T)
head(North_alpha)
# Out:
#   sampleID elevation host obs shannon
# 1 sample1  600       EA   417 5.886450
# 2 sample2  600       EA   352 5.972995
# 3 sample3  600       EA   538 6.084859
# 4 sample4  600       EA   278 4.283397
# 5 sample5  600       EA   295 5.130258
# 6 sample6  600       AL   359 4.842207

# %%
North_alpha_EA = subset(North_alpha, host == "EA")
North_alpha_AL = subset(North_alpha, host == "AL")

# %%
library(BestFitM)

bestFitM(data = North_alpha_EA, x = "elevation", y = "obs")
# Out:
# $BestFitM
#        AIC      BIC  model       formula
# 2 1156.372 1166.588 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model           formula
# 2 1156.372 1166.588  line3P     y = ax^2+bx+c
# 3 1164.480 1174.695   exp3P y = a*exp(b*x)+ c
# 7 1167.271 1177.487 power3P      y = a*x^b+ c
# 4 1171.359 1179.021   log2P       y=a*ln(x)+b
# 6 1173.712 1181.374 power2P         y = a*x^b
# 1 1179.111 1186.773  line2P          y = ax+b
# 5 1181.251 1188.913   exp2P    y = a*exp(b*x)

# %%
bestFitM(data = North_alpha_AL, x = "elevation", y = "obs")
# Out:
# $BestFitM
#        AIC      BIC  model       formula
# 2 1164.508 1174.724 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model           formula
# 2 1164.508 1174.724  line3P     y = ax^2+bx+c
# 3 1184.710 1194.925   exp3P y = a*exp(b*x)+ c
# 7 1186.865 1197.080 power3P      y = a*x^b+ c
# 4 1190.695 1198.357   log2P       y=a*ln(x)+b
# 6 1191.862 1199.524 power2P         y = a*x^b
# 1 1195.905 1203.567  line2P          y = ax+b
# 5 1196.773 1204.435   exp2P    y = a*exp(b*x)

# %%
bestFitM(data = North_alpha_EA, x = "elevation", y = "shannon")
# Out:
# $BestFitM
#        AIC      BIC  model       formula
# 2 199.0146 209.2301 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model           formula
# 2 199.0146 209.2301  line3P     y = ax^2+bx+c
# 3 200.4548 210.6703   exp3P y = a*exp(b*x)+ c
# 7 201.0842 211.2997 power3P      y = a*x^b+ c
# 4 201.4039 209.0655   log2P       y=a*ln(x)+b
# 6 201.7271 209.3887 power2P         y = a*x^b
# 1 204.5733 212.2349  line2P          y = ax+b
# 5 204.9245 212.5861   exp2P    y = a*exp(b*x)

# %%
bestFitM(data = North_alpha_AL, x = "elevation", y = "shannon")
# Out:
# $BestFitM
#        AIC      BIC  model       formula
# 2 178.5842 188.7997 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model           formula
# 2 178.5842 188.7997  line3P     y = ax^2+bx+c
# 3 190.8190 201.0345   exp3P y = a*exp(b*x)+ c
# 7 191.7421 201.9576 power3P      y = a*x^b+ c
# 4 192.4606 200.1223   log2P       y=a*ln(x)+b
# 6 192.6120 200.2736 power2P         y = a*x^b
# 1 194.9037 202.5653  line2P          y = ax+b
# 5 195.0203 202.6820   exp2P    y = a*exp(b*x)

# %%
summary(lm(obs ~ elevation + I(elevation^2), data = North_alpha_EA))
# Out:
# Call:
# lm(formula = obs ~ elevation + I(elevation^2), data = North_alpha_EA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -234.59  -72.20  -11.59   51.57  297.22
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -5.828e+01  8.358e+01  -0.697    0.487
# elevation       7.308e-01  1.210e-01   6.041 3.21e-08 ***
# I(elevation^2) -2.082e-04  3.980e-05  -5.231 1.05e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 103.7 on 92 degrees of freedom
# Multiple R-squared:  0.3836,	Adjusted R-squared:  0.3702
# F-statistic: 28.63 on 2 and 92 DF,  p-value: 2.154e-10

# %%
summary(lm(obs ~ elevation + I(elevation^2), data = North_alpha_AL))
# Out:
# Call:
# lm(formula = obs ~ elevation + I(elevation^2), data = North_alpha_AL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -235.769  -74.467   -4.739   64.774  302.386
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.114e+02  8.724e+01  -1.277    0.205
# elevation       8.421e-01  1.263e-01   6.669 1.89e-09 ***
# I(elevation^2) -2.586e-04  4.155e-05  -6.225 1.41e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 108.2 on 92 degrees of freedom
# Multiple R-squared:  0.3494,	Adjusted R-squared:  0.3353
# F-statistic: 24.71 on 2 and 92 DF,  p-value: 2.582e-09

# %%
summary(lm(shannon ~ elevation + I(elevation^2), data = North_alpha_EA))
# Out:
# Call:
# lm(formula = shannon ~ elevation + I(elevation^2), data = North_alpha_EA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3727 -0.3811  0.1114  0.4542  1.1904
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4.021e+00  5.418e-01   7.422 5.62e-11 ***
# elevation       2.599e-03  7.842e-04   3.314  0.00132 **
# I(elevation^2) -7.122e-07  2.580e-07  -2.760  0.00697 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.672 on 92 degrees of freedom
# Multiple R-squared:  0.1867,	Adjusted R-squared:  0.169
# F-statistic: 10.56 on 2 and 92 DF,  p-value: 7.458e-05

# %%
summary(lm(shannon ~ elevation + I(elevation^2), data = North_alpha_AL))
# Out:
# Call:
# lm(formula = shannon ~ elevation + I(elevation^2), data = North_alpha_AL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.82172 -0.28938  0.01777  0.36879  1.29728
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.739e+00  4.865e-01   7.685 1.62e-11 ***
# elevation       3.287e-03  7.042e-04   4.667 1.03e-05 ***
# I(elevation^2) -1.025e-06  2.317e-07  -4.423 2.66e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6035 on 92 degrees of freedom
# Multiple R-squared:  0.2006,	Adjusted R-squared:  0.1833
# F-statistic: 11.55 on 2 and 92 DF,  p-value: 3.359e-05

# %%
ggplot(data = North_alpha , aes(x = elevation, y = obs , col = host)) +
  geom_point() +
  scale_colour_manual(values =c("#1e90ff","#ff8c00")) +
  geom_vline(aes(xintercept = 1760), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_vline(aes(xintercept = 1630), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2),se = FALSE) +
  labs(x = "Elevation(m)" , y = "Richness") + 
  theme_bw()
# Out:
# plot without title

# %%
ggplot(data = North_alpha , aes(x = elevation, y = shannon , col = host)) +
  geom_point() +
  scale_colour_manual(values =c("#1e90ff","#ff8c00")) +
  geom_vline(aes(xintercept = 1820), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_vline(aes(xintercept = 1600), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2),se = FALSE) +
  labs(x = "Elevation(m)" , y = "Shannon" ) +
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# ### rhizosphere fungal community structure along elevation

# %%
North_otu = read.table(file = "even16271.txt", header = T)
head(North_otu)
# Out:
#                                  sample1 sample2 sample3 sample4 sample5
# 6b9d995dfc0b8c790f9bc6add0cd1c11    0       0    2385       0     0
# b23c0873c3603627c7205163f3df2298    0       0       0       0     5
# 07247b6c736b7b8f32af77ab8de44547    0       0       0       0     0
# 3d2258d3cda1b5305d5d1acc7b4df677    0       0       0       0     0
# a82534894a552a37b7bf6e9fe5baddf5 2073    3565     982    1371    67
# 7a47974ec8aff2c1e5383f2f6e177bb5    2      24      36       4    15
#                                  sample6 sample7 sample8 sample9 sample10 ⋯
# 6b9d995dfc0b8c790f9bc6add0cd1c11  35        5      11     0         0     ⋯
# b23c0873c3603627c7205163f3df2298   0       57       0     0         0     ⋯
# 07247b6c736b7b8f32af77ab8de44547   0       22       9     0         0     ⋯
# 3d2258d3cda1b5305d5d1acc7b4df677   0       32       0     0        19     ⋯
# a82534894a552a37b7bf6e9fe5baddf5 250     1516    1897    46      2001     ⋯
# ...

# %%
map = read.table(file = "map_North.txt", header =T)
head(map)
# Out:
#         elevation host
# sample1 600       EA
# sample2 600       EA
# sample3 600       EA
# sample4 600       EA
# sample5 600       EA
# sample6 600       AL

# %%
library(vegan)

set.seed(100)

ord_North = metaMDS(t(North_otu))
# Out:
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1479167
# Run 1 stress 0.1587577
# Run 2 stress 0.1583045
# Run 3 stress 0.1468317
# ... New best solution
# ... Procrustes: rmse 0.01281553  max resid 0.1550345
# Run 4 stress 0.1537901
# Run 5 stress 0.1556853
# Run 6 stress 0.1452047
# ... New best solution
# ... Procrustes: rmse 0.01039907  max resid 0.138289
# Run 7 stress 0.1668786
# Run 8 stress 0.1448167
# ... New best solution
# ... Procrustes: rmse 0.004642916  max resid 0.060619
# Run 9 stress 0.1463625
# Run 10 stress 0.1747264
# Run 11 stress 0.1680216
# Run 12 stress 0.1448195
# ... Procrustes: rmse 0.0003569483  max resid 0.003697327
# ... Similar to previous best
# Run 13 stress 0.1529776
# Run 14 stress 0.1452039
# ... Procrustes: rmse 0.004745837  max resid 0.06074457
# Run 15 stress 0.1531101
# Run 16 stress 0.1561292
# Run 17 stress 0.154369
# Run 18 stress 0.1448165
# ... New best solution
# ...

# %%
NMDS_north = scores(ord_North)
NMDS_north_plot = cbind(NMDS_north, map)
head(NMDS_north_plot)
# Out:
#         NMDS1      NMDS2         elevation host
# sample1 -0.2791693 -0.0031225182 600       EA
# sample2 -0.3399921 -0.0807492939 600       EA
# sample3 -0.1881743 -0.1098834489 600       EA
# sample4 -0.2896399  0.0078677520 600       EA
# sample5 -0.3954569 -0.0026620986 600       EA
# sample6 -0.3243845 -0.0004638127 600       AL

# %%
ggplot(data = NMDS_north_plot , aes(x = NMDS1, y = NMDS2 , col = host, size = elevation)) +
  geom_point() +
  scale_colour_manual(values =c("#1e90ff","#ff8c00")) +
  scale_size(range=c(1,9.5)) +
  labs(x = "NMDS1" , y = "NMDS2" ) +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(data = NMDS_north_plot , aes(x = NMDS1, y = NMDS2 , col = host)) +
  geom_point() +
  scale_colour_manual(values =c("#1e90ff","#ff8c00")) +
  facet_wrap(~elevation, scale = "free") +
  labs(x = "NMDS1" , y = "NMDS2" ) +
  theme_bw()
# Out:
# plot without title

# %%
set.seed(100)

adonis2(t(North_otu) ~ factor(elevation) * host, data =  map)
# Out:
#                        Df  SumOfSqs  R2        F        Pr(>F)
# factor(elevation)       18 19.880298 0.2903847 4.298475 0.001
# host                     1  1.644305 0.0240178 6.399505 0.001
# factor(elevation):host  18  7.882064 0.1151306 1.704243 0.001
# Residual               152 39.055260 0.5704669       NA    NA
# Total                  189 68.461927 1.0000000       NA    NA

# %%
library(tidyr)
map_1 = unite(map, "treat", elevation, host, remove = FALSE)
head(map_1)
# Out:
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.5”
#         treat  elevation host
# sample1 600_EA 600       EA
# sample2 600_EA 600       EA
# sample3 600_EA 600       EA
# sample4 600_EA 600       EA
# sample5 600_EA 600       EA
# sample6 600_AL 600       AL

# %%
map_600 = subset(map, elevation == "600")
North_otu_600 = North_otu[,rownames(map_600)]
North_otu_600 = North_otu_600[which(rowSums(North_otu_600)>0),]
set.seed(100)
adonis2(t(North_otu_600) ~ host, data = map_600)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.3095084 0.1185227 1.075673 0.336
# Residual 8  2.3018771 0.8814773       NA    NA
# Total    9  2.6113855 1.0000000       NA    NA

# %%
map_700 = subset(map, elevation == "700")
North_otu_700 = North_otu[,rownames(map_700)]
North_otu_700 = North_otu_700[which(rowSums(North_otu_700)>0),]
set.seed(100)
adonis2(t(North_otu_700) ~ host, data = map_700)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.3427329 0.1184134 1.074548 0.328
# Residual 8  2.5516432 0.8815866       NA    NA
# Total    9  2.8943761 1.0000000       NA    NA

# %%
map_800 = subset(map, elevation == "800")
North_otu_800 = North_otu[,rownames(map_800)]
North_otu_800 = North_otu_800[which(rowSums(North_otu_800)>0),]
set.seed(100)
adonis2(t(North_otu_800) ~ host, data = map_800)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.4439515 0.1915772 1.895811 0.01
# Residual 8  1.8733994 0.8084228       NA   NA
# Total    9  2.3173509 1.0000000       NA   NA

# %%
map_900 = subset(map, elevation == "900")
North_otu_900 = North_otu[,rownames(map_900)]
North_otu_900 = North_otu_900[which(rowSums(North_otu_900)>0),]
set.seed(100)
adonis2(t(North_otu_900) ~ host, data = map_900)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.6475308 0.2194747 2.249508 0.01
# Residual 8  2.3028352 0.7805253       NA   NA
# Total    9  2.9503660 1.0000000       NA   NA

# %%
map_1000 = subset(map, elevation == "1000")
North_otu_1000 = North_otu[,rownames(map_1000)]
North_otu_1000 = North_otu_1000[which(rowSums(North_otu_1000)>0),]
set.seed(100)
adonis2(t(North_otu_1000) ~ host, data = map_1000)
# Out:
#          Df SumOfSqs  R2        F       Pr(>F)
# host     1  0.5271533 0.2121843 2.15466 0.01
# Residual 8  1.9572586 0.7878157      NA   NA
# Total    9  2.4844119 1.0000000      NA   NA

# %%
map_1100 = subset(map, elevation == "1100")
North_otu_1100 = North_otu[,rownames(map_1100)]
North_otu_1100 = North_otu_1100[which(rowSums(North_otu_1100)>0),]
set.seed(100)
adonis2(t(North_otu_1100) ~ host, data = map_1100)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.4573657 0.2256056 2.330653 0.01
# Residual 8  1.5699139 0.7743944       NA   NA
# Total    9  2.0272796 1.0000000       NA   NA

# %%
map_1200 = subset(map, elevation == "1200")
North_otu_1200 = North_otu[,rownames(map_1200)]
North_otu_1200 = North_otu_1200[which(rowSums(North_otu_1200)>0),]
set.seed(100)
adonis2(t(North_otu_1200) ~ host, data = map_1200)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.3891209 0.1425311 1.329784 0.052
# Residual 8  2.3409570 0.8574689       NA    NA
# Total    9  2.7300779 1.0000000       NA    NA

# %%
map_1300 = subset(map, elevation == "1300")
North_otu_1300 = North_otu[,rownames(map_1300)]
North_otu_1300 = North_otu_1300[which(rowSums(North_otu_1300)>0),]
set.seed(1000)
adonis2(t(North_otu_1300) ~ host, data = map_1300)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.8299275 0.3145672 3.671458 0.01
# Residual 8  1.8083878 0.6854328       NA   NA
# Total    9  2.6383153 1.0000000       NA   NA

# %%
map_1400 = subset(map, elevation == "1400")
North_otu_1400 = North_otu[,rownames(map_1400)]
North_otu_1400 = North_otu_1400[which(rowSums(North_otu_1400)>0),]
set.seed(1000)
adonis2(t(North_otu_1400) ~ host, data = map_1400)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.5358664 0.2289434 2.375373 0.01
# Residual 8  1.8047403 0.7710566       NA   NA
# Total    9  2.3406067 1.0000000       NA   NA

# %%
map_1500 = subset(map, elevation == "1500")
North_otu_1500 = North_otu[,rownames(map_1500)]
North_otu_1500 = North_otu_1500[which(rowSums(North_otu_1500)>0),]
set.seed(100)
adonis2(t(North_otu_1500) ~ host, data = map_1500)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.5233966 0.1989556 1.986963 0.01
# Residual 8  2.1073232 0.8010444       NA   NA
# Total    9  2.6307198 1.0000000       NA   NA

# %%
map_1600 = subset(map, elevation == "1600")
North_otu_1600 = North_otu[,rownames(map_1600)]
North_otu_1600 = North_otu_1600[which(rowSums(North_otu_1600)>0),]
set.seed(100)
adonis2(t(North_otu_1600) ~ host, data = map_1600)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.5547447 0.2032304 2.040544 0.016
# Residual 8  2.1748895 0.7967696       NA    NA
# Total    9  2.7296341 1.0000000       NA    NA

# %%
map_1700 = subset(map, elevation == "1700")
North_otu_1700 = North_otu[,rownames(map_1700)]
North_otu_1700 = North_otu_1700[which(rowSums(North_otu_1700)>0),]
set.seed(100)
adonis2(t(North_otu_1700) ~ host, data = map_1700)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.5400231 0.2173971 2.222298 0.01
# Residual 8  1.9440172 0.7826029       NA   NA
# Total    9  2.4840403 1.0000000       NA   NA

# %%
map_1800 = subset(map, elevation == "1800")
North_otu_1800 = North_otu[,rownames(map_1800)]
North_otu_1800 = North_otu_1800[which(rowSums(North_otu_1800)>0),]
set.seed(100)
adonis2(t(North_otu_1800) ~ host, data = map_1800)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.6290489 0.2187974 2.240622 0.01
# Residual 8  2.2459797 0.7812026       NA   NA
# Total    9  2.8750286 1.0000000       NA   NA

# %%
map_1900 = subset(map, elevation == "1900")
North_otu_1900 = North_otu[,rownames(map_1900)]
North_otu_1900 = North_otu_1900[which(rowSums(North_otu_1900)>0),]
set.seed(100)
adonis2(t(North_otu_1900) ~ host, data = map_1900)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.4393381 0.2237779 2.306329 0.01
# Residual 8  1.5239389 0.7762221       NA   NA
# Total    9  1.9632770 1.0000000       NA   NA

# %%
map_2000 = subset(map, elevation == "2000")
North_otu_2000 = North_otu[,rownames(map_2000)]
North_otu_2000 = North_otu_2000[which(rowSums(North_otu_2000)>0),]
set.seed(100)
adonis2(t(North_otu_2000) ~ host, data = map_2000)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.3645047 0.1448899 1.355521 0.109
# Residual 8  2.1512304 0.8551101       NA    NA
# Total    9  2.5157351 1.0000000       NA    NA

# %%
map_2100 = subset(map, elevation == "2100")
North_otu_2100 = North_otu[,rownames(map_2100)]
North_otu_2100 = North_otu_2100[which(rowSums(North_otu_2100)>0),]
set.seed(100)
adonis2(t(North_otu_2100) ~ host, data = map_2100)
# Out:
#          Df SumOfSqs  R2       F        Pr(>F)
# host     1  0.6757594 0.259823 2.808226 0.01
# Residual 8  1.9250854 0.740177       NA   NA
# Total    9  2.6008447 1.000000       NA   NA

# %%
map_2200 = subset(map, elevation == "2200")
North_otu_2200 = North_otu[,rownames(map_2200)]
North_otu_2200 = North_otu_2200[which(rowSums(North_otu_2200)>0),]
set.seed(100)
adonis2(t(North_otu_2200) ~ host, data = map_2200)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.3369376 0.1262948 1.156407 0.216
# Residual 8  2.3309276 0.8737052       NA    NA
# Total    9  2.6678652 1.0000000       NA    NA

# %%
map_2300 = subset(map, elevation == "2300")
North_otu_2300 = North_otu[,rownames(map_2300)]
North_otu_2300 = North_otu_2300[which(rowSums(North_otu_2300)>0),]
set.seed(100)
adonis2(t(North_otu_2300) ~ host, data = map_2300)
# Out:
#          Df SumOfSqs  R2        F        Pr(>F)
# host     1  0.4918155 0.2084589 2.106866 0.01
# Residual 8  1.8674768 0.7915411       NA   NA
# Total    9  2.3592923 1.0000000       NA   NA

# %%
map_2400 = subset(map, elevation == "2400")
North_otu_2400 = North_otu[,rownames(map_2400)]
North_otu_2400 = North_otu_2400[which(rowSums(North_otu_2400)>0),]
set.seed(100)
adonis2(t(North_otu_2400) ~ host, data = map_2400)
# Out:
#          Df SumOfSqs R2        F        Pr(>F)
# host     1  0.487643 0.1766169 1.716012 0.01
# Residual 8  2.273379 0.8233831       NA   NA
# Total    9  2.761022 1.0000000       NA   NA

# %% [markdown]
# ### Mutualism and plant pathogen along elevation

# %%
Guild = read.table(file = "Guild.txt", header = T)
head(Guild)
# Out:
#   sampleID Fusarium   Plant_Pathogen Mutualism   Saprotroph elevation host
# 1 sample1  0.06595241 0.03936183     0.005978029 0.38826132 600       EA
# 2 sample2  0.01542320 0.03324224     0.025642945 0.33294651 600       EA
# 3 sample3  0.02032851 0.02158420     0.005837236 0.34052807 600       EA
# 4 sample4  0.01380690 0.01100550     0.007378689 0.13956979 600       EA
# 5 sample5  0.04473288 0.02834502     0.004515891 0.13570394 600       EA
# 6 sample6  0.06850000 0.03601236     0.008307573 0.09049459 600       AL

# %%
Guild_EA = subset(Guild, host == "EA")
Guild_AL = subset(Guild, host == "AL")

# %%
bestFitM2(data = Guild_AL, x = "elevation", y = "Plant_Pathogen")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -397.7914 -387.5759 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -397.7914 -387.5759  line3P  y = ax^2+bx+c
# 1 -393.2295 -385.5678  line2P       y = ax+b
# 4 -392.8721 -385.2105   exp2P y = a*exp(b*x)
# 3 -392.0931 -384.4315   log2P    y=a*ln(x)+b
# 5 -391.9246 -384.2630 power2P      y = a*x^b

# %%
summary(lm(Plant_Pathogen~elevation + I(elevation^2), data =  Guild_AL))
# Out:
# Call:
# lm(formula = Plant_Pathogen ~ elevation + I(elevation^2), data = Guild_AL)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027884 -0.015338 -0.004911  0.006455  0.201102
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -9.086e-03  2.342e-02  -0.388   0.6990
# elevation       7.771e-05  3.391e-05   2.292   0.0242 *
# I(elevation^2) -2.861e-08  1.116e-08  -2.565   0.0119 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02905 on 92 degrees of freedom
# Multiple R-squared:  0.08742,	Adjusted R-squared:  0.06759
# F-statistic: 4.407 on 2 and 92 DF,  p-value: 0.01487

# %%
bestFitM2(data = Guild_EA, x = "elevation", y = "Plant_Pathogen")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -396.7019 -386.4864 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -396.7019 -386.4864  line3P  y = ax^2+bx+c
# 1 -385.6041 -377.9424  line2P       y = ax+b
# 4 -384.8170 -377.1554   exp2P y = a*exp(b*x)
# 3 -383.2167 -375.5551   log2P    y=a*ln(x)+b
# 5 -382.8413 -375.1797 power2P      y = a*x^b

# %%
summary(lm(Plant_Pathogen~elevation + I(elevation^2), data =  Guild_EA))
# Out:
# Call:
# lm(formula = Plant_Pathogen ~ elevation + I(elevation^2), data = Guild_EA)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.044255 -0.017998 -0.006011  0.010369  0.096076
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.896e-02  2.356e-02  -0.805 0.422920
# elevation       1.123e-04  3.410e-05   3.292 0.001412 **
# I(elevation^2) -4.138e-08  1.122e-08  -3.688 0.000382 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02922 on 92 degrees of freedom
# Multiple R-squared:  0.1659,	Adjusted R-squared:  0.1478
# F-statistic: 9.151 on 2 and 92 DF,  p-value: 0.0002374

# %%
ggplot(data = Guild , aes(x = elevation, y = Plant_Pathogen , col = host)) +
  geom_point() +
  scale_colour_manual(values =c("#1e90ff","#ff8c00")) +
  geom_vline(aes(xintercept = 1360), colour = "#ff8c00", linetype = "dashed", size =1, alpha = 0.4) +
  geom_vline(aes(xintercept = 1360), colour = "#1e90ff", linetype = "dashed", size =1, alpha = 0.4) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2),se = FALSE) +
  labs(x = "Elevation(m)" , y = "Relativa abundance of plant pathogen" ) +
  theme_bw()
# Out:
# plot without title

# %%
bestFitM2(data = Guild_EA, x = "elevation", y = "Mutualism")
# Out:
# $BestFitM2
#        AIC       BIC model     formula
# 3 -451.426 -443.7644 log2P y=a*ln(x)+b
#
# $AllModel
#         AIC       BIC   model        formula
# 3 -451.4260 -443.7644   log2P    y=a*ln(x)+b
# 1 -449.9980 -442.3364  line2P       y = ax+b
# 5 -449.9270 -442.2654 power2P      y = a*x^b
# 2 -449.8586 -439.6431  line3P  y = ax^2+bx+c
# 4 -447.3349 -439.6732   exp2P y = a*exp(b*x)

# %%
summary(lm(Mutualism~elevation, data =  Guild_EA))
# Out:
# Call:
# lm(formula = Mutualism ~ elevation, data = Guild_EA)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.035853 -0.012958 -0.004946  0.012364  0.103142
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.751e-03  6.636e-03  -0.264    0.792
# elevation    2.113e-05  4.156e-06   5.083 1.91e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02219 on 93 degrees of freedom
# Multiple R-squared:  0.2174,	Adjusted R-squared:  0.209
# F-statistic: 25.84 on 1 and 93 DF,  p-value: 1.911e-06

# %%
bestFitM2(data = Guild_AL, x = "elevation", y = "Mutualism")
# Out:
# Error in nls(y ~ a * (x^b), start = list(a = a_power2P, b = b_power2P)): number of iterations exceeded maximum of 50
# Traceback:
#
# 1. bestFitM2(data = Guild_AL, x = "elevation", y = "Mutualism")
# 2. nls(y ~ a * (x^b), start = list(a = a_power2P, b = b_power2P))

# %%
AIC(lm(Mutualism~elevation, data =  Guild_AL))
AIC(lm(Mutualism~elevation + I(elevation^2), data =  Guild_AL))
# Out:
# [1] -357.3705
# [1] -371.5161

# %%
BIC(lm(Mutualism~elevation, data =  Guild_AL))
BIC(lm(Mutualism~elevation + I(elevation^2), data =  Guild_AL))
# Out:
# [1] -349.7088
# [1] -361.3006

# %%
summary(lm(Mutualism~elevation + I(elevation^2), data =  Guild_AL))
# Out:
# Call:
# lm(formula = Mutualism ~ elevation + I(elevation^2), data = Guild_AL)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.048756 -0.023986 -0.005935  0.014260  0.120044
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -9.575e-02  2.690e-02  -3.560  0.00059 ***
# elevation       1.839e-04  3.893e-05   4.723 8.31e-06 ***
# I(elevation^2) -5.288e-08  1.281e-08  -4.128 8.03e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03336 on 92 degrees of freedom
# Multiple R-squared:  0.266,	Adjusted R-squared:  0.2501
# F-statistic: 16.67 on 2 and 92 DF,  p-value: 6.623e-07

# %%
Guild2 = read.table(file = "Guild2.txt", header =T)
head(Guild2)
# Out:
#   sampleID EA_Mutualism EA_Saprotroph elevation AL_Mutualism AL_Saprotroph
# 1 sample1  0.005978029  0.3882613     600       0.008307573  0.09049459
# 2 sample2  0.025642945  0.3329465     600       0.006035889  0.38633768
# 3 sample3  0.005837236  0.3405281     600       0.019728351  0.23379018
# 4 sample4  0.007378689  0.1395698     600       0.012669839  0.18798372
# 5 sample5  0.004515891  0.1357039     600       0.004791977  0.28031481
# 6 sample11 0.001440000  0.4353444     700       0.003691719  0.11653981

# %%
ggplot(data = Guild2 , aes(x = elevation, y = EA_Mutualism)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_Mutualism), color = "#1e90ff") +
  geom_smooth(method = "lm",se = FALSE, color = "#ff8c00") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,
              aes(elevation, AL_Mutualism)) +
  geom_vline(aes(xintercept = 1740), colour = "#1e90ff", linetype = "dashed", size =1) +
  labs(x = "Elevation(m)" , y = "Relativa abundance of Mutualism" ) +
  theme_bw()
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ### host specialization

# %%
library("bipartite")
library("ggplot2")
# Out:
# Loading required package: sna
#
# Loading required package: statnet.common
#
#
# Attaching package: ‘statnet.common’
#
#
# The following objects are masked from ‘package:base’:
#
#     attr, order
#
#
# Loading required package: network
#
#
# ‘network’ 1.17.1 (2021-06-12), part of the Statnet Project
# * ‘news(package="network")’ for changes since last version
# * ‘citation("network")’ for citation information
# * ‘https://statnet.org’ for help, support, and other information
#
#
# sna: Tools for Social Network Analysis
# Version 2.6 created on 2020-10-5.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#  For citation information, type citation("sna").
#  Type help(package="sna") to get started.
#
#
#  This is bipartite 2.16.
#  For latest changes see versionlog in ?"bipartite-package". For citation see: citation("bipartite").
#  Have a nice time plotting and analysing two-mode networks.
#
#
# Attaching package: ‘bipartite’
#
#
# ...

# %%
North_otu = read.table(file = "even16271.txt", header = T)
head(North_otu)
North_map = read.table(file = "map_North.txt", header = T)
head(North_map)
# Out:
#                                  sample1 sample2 sample3 sample4 sample5
# 6b9d995dfc0b8c790f9bc6add0cd1c11    0       0    2385       0     0
# b23c0873c3603627c7205163f3df2298    0       0       0       0     5
# 07247b6c736b7b8f32af77ab8de44547    0       0       0       0     0
# 3d2258d3cda1b5305d5d1acc7b4df677    0       0       0       0     0
# a82534894a552a37b7bf6e9fe5baddf5 2073    3565     982    1371    67
# 7a47974ec8aff2c1e5383f2f6e177bb5    2      24      36       4    15
#                                  sample6 sample7 sample8 sample9 sample10 ⋯
# 6b9d995dfc0b8c790f9bc6add0cd1c11  35        5      11     0         0     ⋯
# b23c0873c3603627c7205163f3df2298   0       57       0     0         0     ⋯
# 07247b6c736b7b8f32af77ab8de44547   0       22       9     0         0     ⋯
# 3d2258d3cda1b5305d5d1acc7b4df677   0       32       0     0        19     ⋯
# a82534894a552a37b7bf6e9fe5baddf5 250     1516    1897    46      2001     ⋯
# ...

# %%
library(tidyr)
North_map1 = unite(North_map, "treat", elevation, host, remove = FALSE)
head(North_map1)
# Out:
#         treat  elevation host
# sample1 600_EA 600       EA
# sample2 600_EA 600       EA
# sample3 600_EA 600       EA
# sample4 600_EA 600       EA
# sample5 600_EA 600       EA
# sample6 600_AL 600       AL

# %%
North_otu = t(North_otu)
EA_600_North_meta = subset(North_map1, treat == "600_EA")
EA_600_North_otu = North_otu[rownames(EA_600_North_meta), ]
EA_600_North_sums = rbind.data.frame(colSums(EA_600_North_otu))
colnames(EA_600_North_sums) = colnames(North_otu)
row.names(EA_600_North_sums) = "EA_600_North"

# %%
EA_600_North_meta = EA_600_North_meta[1, ]
row.names(EA_600_North_meta) = row.names(EA_600_North_sums)

# %%
EA_700_North_meta = subset(North_map1, treat == "700_EA")
EA_700_North_otu = North_otu[rownames(EA_700_North_meta), ]
EA_700_North_sums = rbind.data.frame(colSums(EA_700_North_otu))
colnames(EA_700_North_sums) = colnames(North_otu)
row.names(EA_700_North_sums) = "EA_700_North"

# %%
EA_700_North_meta = EA_700_North_meta[1, ]
row.names(EA_700_North_meta) = row.names(EA_700_North_sums)

# %%
EA_800_North_meta = subset(North_map1, treat == "800_EA")
EA_800_North_otu = North_otu[rownames(EA_800_North_meta), ]
EA_800_North_sums = rbind.data.frame(colSums(EA_800_North_otu))
colnames(EA_800_North_sums) = colnames(North_otu)
row.names(EA_800_North_sums) = "EA_800_North"

# %%
EA_800_North_meta = EA_800_North_meta[1, ]
row.names(EA_800_North_meta) = row.names(EA_800_North_sums)

# %%
EA_900_North_meta = subset(North_map1, treat == "900_EA")
EA_900_North_otu = North_otu[rownames(EA_900_North_meta), ]
EA_900_North_sums = rbind.data.frame(colSums(EA_900_North_otu))
colnames(EA_900_North_sums) = colnames(North_otu)
row.names(EA_900_North_sums) = "EA_900_North"

# %%
EA_900_North_meta = EA_900_North_meta[1, ]
row.names(EA_900_North_meta) = row.names(EA_900_North_sums)

# %%
EA_1000_North_meta = subset(North_map1, treat == "1000_EA")
EA_1000_North_otu = North_otu[rownames(EA_1000_North_meta), ]
EA_1000_North_sums = rbind.data.frame(colSums(EA_1000_North_otu))
colnames(EA_1000_North_sums) = colnames(North_otu)
row.names(EA_1000_North_sums) = "EA_1000_North"

EA_1000_North_meta = EA_1000_North_meta[1, ]
row.names(EA_1000_North_meta) = row.names(EA_1000_North_sums)

# %%
EA_1100_North_meta = subset(North_map1, treat == "1100_EA")
EA_1100_North_otu = North_otu[rownames(EA_1100_North_meta), ]
EA_1100_North_sums = rbind.data.frame(colSums(EA_1100_North_otu))
colnames(EA_1100_North_sums) = colnames(North_otu)
row.names(EA_1100_North_sums) = "EA_1100_North"

EA_1100_North_meta = EA_1100_North_meta[1, ]
row.names(EA_1100_North_meta) = row.names(EA_1100_North_sums)

# %%
EA_1200_North_meta = subset(North_map1, treat == "1200_EA")
EA_1200_North_otu = North_otu[rownames(EA_1200_North_meta), ]
EA_1200_North_sums = rbind.data.frame(colSums(EA_1200_North_otu))
colnames(EA_1200_North_sums) = colnames(North_otu)
row.names(EA_1200_North_sums) = "EA_1200_North"

EA_1200_North_meta = EA_1200_North_meta[1, ]
row.names(EA_1200_North_meta) = row.names(EA_1200_North_sums)

# %%
EA_1300_North_meta = subset(North_map1, treat == "1300_EA")
EA_1300_North_otu = North_otu[rownames(EA_1300_North_meta), ]
EA_1300_North_sums = rbind.data.frame(colSums(EA_1300_North_otu))
colnames(EA_1300_North_sums) = colnames(North_otu)
row.names(EA_1300_North_sums) = "EA_1300_North"

EA_1300_North_meta = EA_1300_North_meta[1, ]
row.names(EA_1300_North_meta) = row.names(EA_1300_North_sums)

# %%
EA_1400_North_meta = subset(North_map1, treat == "1400_EA")
EA_1400_North_otu = North_otu[rownames(EA_1400_North_meta), ]
EA_1400_North_sums = rbind.data.frame(colSums(EA_1400_North_otu))
colnames(EA_1400_North_sums) = colnames(North_otu)
row.names(EA_1400_North_sums) = "EA_1400_North"

EA_1400_North_meta = EA_1400_North_meta[1, ]
row.names(EA_1400_North_meta) = row.names(EA_1400_North_sums)

# %%
EA_1500_North_meta = subset(North_map1, treat == "1500_EA")
EA_1500_North_otu = North_otu[rownames(EA_1500_North_meta), ]
EA_1500_North_sums = rbind.data.frame(colSums(EA_1500_North_otu))
colnames(EA_1500_North_sums) = colnames(North_otu)
row.names(EA_1500_North_sums) = "EA_1500_North"

EA_1500_North_meta = EA_1500_North_meta[1, ]
row.names(EA_1500_North_meta) = row.names(EA_1500_North_sums)

# %%
EA_1600_North_meta = subset(North_map1, treat == "1600_EA")
EA_1600_North_otu = North_otu[rownames(EA_1600_North_meta), ]
EA_1600_North_sums = rbind.data.frame(colSums(EA_1600_North_otu))
colnames(EA_1600_North_sums) = colnames(North_otu)
row.names(EA_1600_North_sums) = "EA_1600_North"

EA_1600_North_meta = EA_1600_North_meta[1, ]
row.names(EA_1600_North_meta) = row.names(EA_1600_North_sums)

# %%
EA_1700_North_meta = subset(North_map1, treat == "1700_EA")
EA_1700_North_otu = North_otu[rownames(EA_1700_North_meta), ]
EA_1700_North_sums = rbind.data.frame(colSums(EA_1700_North_otu))
colnames(EA_1700_North_sums) = colnames(North_otu)
row.names(EA_1700_North_sums) = "EA_1700_North"

EA_1700_North_meta = EA_1700_North_meta[1, ]
row.names(EA_1700_North_meta) = row.names(EA_1700_North_sums)

# %%
EA_1800_North_meta = subset(North_map1, treat == "1800_EA")
EA_1800_North_otu = North_otu[rownames(EA_1800_North_meta), ]
EA_1800_North_sums = rbind.data.frame(colSums(EA_1800_North_otu))
colnames(EA_1800_North_sums) = colnames(North_otu)
row.names(EA_1800_North_sums) = "EA_1800_North"

EA_1800_North_meta = EA_1800_North_meta[1, ]
row.names(EA_1800_North_meta) = row.names(EA_1800_North_sums)

# %%
EA_1900_North_meta = subset(North_map1, treat == "1900_EA")
EA_1900_North_otu = North_otu[rownames(EA_1900_North_meta), ]
EA_1900_North_sums = rbind.data.frame(colSums(EA_1900_North_otu))
colnames(EA_1900_North_sums) = colnames(North_otu)
row.names(EA_1900_North_sums) = "EA_1900_North"

EA_1900_North_meta = EA_1900_North_meta[1, ]
row.names(EA_1900_North_meta) = row.names(EA_1900_North_sums)

# %%
EA_2000_North_meta = subset(North_map1, treat == "2000_EA")
EA_2000_North_otu = North_otu[rownames(EA_2000_North_meta), ]
EA_2000_North_sums = rbind.data.frame(colSums(EA_2000_North_otu))
colnames(EA_2000_North_sums) = colnames(North_otu)
row.names(EA_2000_North_sums) = "EA_2000_North"

EA_2000_North_meta = EA_2000_North_meta[1, ]
row.names(EA_2000_North_meta) = row.names(EA_2000_North_sums)

# %%
EA_2100_North_meta = subset(North_map1, treat == "2100_EA")
EA_2100_North_otu = North_otu[rownames(EA_2100_North_meta), ]
EA_2100_North_sums = rbind.data.frame(colSums(EA_2100_North_otu))
colnames(EA_2100_North_sums) = colnames(North_otu)
row.names(EA_2100_North_sums) = "EA_2100_North"

EA_2100_North_meta = EA_2100_North_meta[1, ]
row.names(EA_2100_North_meta) = row.names(EA_2100_North_sums)

# %%
EA_2200_North_meta = subset(North_map1, treat == "2200_EA")
EA_2200_North_otu = North_otu[rownames(EA_2200_North_meta), ]
EA_2200_North_sums = rbind.data.frame(colSums(EA_2200_North_otu))
colnames(EA_2200_North_sums) = colnames(North_otu)
row.names(EA_2200_North_sums) = "EA_2200_North"

EA_2200_North_meta = EA_2200_North_meta[1, ]
row.names(EA_2200_North_meta) = row.names(EA_2200_North_sums)

# %%
EA_2300_North_meta = subset(North_map1, treat == "2300_EA")
EA_2300_North_otu = North_otu[rownames(EA_2300_North_meta), ]
EA_2300_North_sums = rbind.data.frame(colSums(EA_2300_North_otu))
colnames(EA_2300_North_sums) = colnames(North_otu)
row.names(EA_2300_North_sums) = "EA_2300_North"

EA_2300_North_meta = EA_2300_North_meta[1, ]
row.names(EA_2300_North_meta) = row.names(EA_2300_North_sums)

# %%
EA_2400_North_meta = subset(North_map1, treat == "2400_EA")
EA_2400_North_otu = North_otu[rownames(EA_2400_North_meta), ]
EA_2400_North_sums = rbind.data.frame(colSums(EA_2400_North_otu))
colnames(EA_2400_North_sums) = colnames(North_otu)
row.names(EA_2400_North_sums) = "EA_2400_North"

EA_2400_North_meta = EA_2400_North_meta[1, ]
row.names(EA_2400_North_meta) = row.names(EA_2400_North_sums)

# %%
EA_North_1 = rbind.data.frame(EA_600_North_sums,EA_700_North_sums,EA_800_North_sums,EA_900_North_sums)
EA_North_1_prime = dfun(EA_North_1)
EA_North_1_prime
# Out:
# $dprime
# EA_600_North EA_700_North EA_800_North EA_900_North
#    0.3531488    0.3813264    0.5204497    0.4477860
#
# $d
# EA_600_North EA_700_North EA_800_North EA_900_North
#    0.4908764    0.5298817    0.7224663    0.6218799
#
# $dmin
# EA_600_North EA_700_North EA_800_North EA_900_North
#  0.002022345  0.002022345  0.002022345  0.002022345
#
# $dmax
# EA_600_North EA_700_North EA_800_North EA_900_North
#     1.386294     1.386294     1.386294     1.386294

# %%
EA_North_2 = rbind.data.frame(EA_1000_North_sums,EA_1100_North_sums,EA_1200_North_sums,EA_1300_North_sums)
EA_North_2_prime = dfun(EA_North_2)
EA_North_2_prime
# Out:
# $dprime
# EA_1000_North EA_1100_North EA_1200_North EA_1300_North
#     0.5631456     0.4954666     0.4952644     0.5038632
#
# $d
# EA_1000_North EA_1100_North EA_1200_North EA_1300_North
#     0.7821985     0.6886099     0.6883304     0.7002210
#
# $dmin
# EA_1000_North EA_1100_North EA_1200_North EA_1300_North
#   0.003463389   0.003463389   0.003463389   0.003463389
#
# $dmax
# EA_1000_North EA_1100_North EA_1200_North EA_1300_North
#      1.386294      1.386294      1.386294      1.386294

# %%
EA_North_3 = rbind.data.frame(EA_1400_North_sums,EA_1500_North_sums,EA_1600_North_sums,EA_1700_North_sums)
EA_North_3_prime = dfun(EA_North_3)
EA_North_3_prime
# Out:
# $dprime
# EA_1400_North EA_1500_North EA_1600_North EA_1700_North
#     0.4945476     0.3774259     0.4281007     0.4568728
#
# $d
# EA_1400_North EA_1500_North EA_1600_North EA_1700_North
#     0.6873719     0.5254199     0.5954914     0.6352765
#
# $dmin
# EA_1400_North EA_1500_North EA_1600_North EA_1700_North
#   0.003528206   0.003528206   0.003528206   0.003528206
#
# $dmax
# EA_1400_North EA_1500_North EA_1600_North EA_1700_North
#      1.386294      1.386294      1.386294      1.386294

# %%
EA_North_4 = rbind.data.frame(EA_1800_North_sums,EA_1900_North_sums,EA_2000_North_sums,EA_2100_North_sums)
EA_North_4_prime = dfun(EA_North_4)
EA_North_4_prime
# Out:
# $dprime
# EA_1800_North EA_1900_North EA_2000_North EA_2100_North
#     0.5389986     0.4370579     0.3534671     0.4766172
#
# $d
# EA_1800_North EA_1900_North EA_2000_North EA_2100_North
#     0.7488701     0.6079172     0.4923366     0.6626157
#
# $dmin
# EA_1800_North EA_1900_North EA_2000_North EA_2100_North
#   0.003599491   0.003599491   0.003599491   0.003599491
#
# $dmax
# EA_1800_North EA_1900_North EA_2000_North EA_2100_North
#      1.386294      1.386294      1.386294      1.386294

# %%
EA_North_5 = rbind.data.frame(EA_2200_North_sums,EA_2300_North_sums,EA_2400_North_sums)
EA_North_5_prime = dfun(EA_North_5)
EA_North_5_prime
# Out:
# $dprime
# EA_2200_North EA_2300_North EA_2400_North
#     0.5381404     0.4816511     0.4411643
#
# $d
# EA_2200_North EA_2300_North EA_2400_North
#     0.5921028     0.5301524     0.4857516
#
# $dmin
# EA_2200_North EA_2300_North EA_2400_North
#   0.001938005   0.001938005   0.001938005
#
# $dmax
# EA_2200_North EA_2300_North EA_2400_North
#      1.098612      1.098612      1.098612

# %%
AL_600_North_meta = subset(North_map1, treat == "600_AL")
AL_600_North_otu = North_otu[rownames(AL_600_North_meta), ]
AL_600_North_sums = rbind.data.frame(colSums(AL_600_North_otu))
colnames(AL_600_North_sums) = colnames(North_otu)
row.names(AL_600_North_sums) = "AL_600_North"

# %%
AL_700_North_meta = subset(North_map1, treat == "700_AL")
AL_700_North_otu = North_otu[rownames(AL_700_North_meta), ]
AL_700_North_sums = rbind.data.frame(colSums(AL_700_North_otu))
colnames(AL_700_North_sums) = colnames(North_otu)
row.names(AL_700_North_sums) = "AL_700_North"

# %%
AL_800_North_meta = subset(North_map1, treat == "800_AL")
AL_800_North_otu = North_otu[rownames(AL_800_North_meta), ]
AL_800_North_sums = rbind.data.frame(colSums(AL_800_North_otu))
colnames(AL_800_North_sums) = colnames(North_otu)
row.names(AL_800_North_sums) = "AL_800_North"

# %%
AL_900_North_meta = subset(North_map1, treat == "900_AL")
AL_900_North_otu = North_otu[rownames(AL_900_North_meta), ]
AL_900_North_sums = rbind.data.frame(colSums(AL_900_North_otu))
colnames(AL_900_North_sums) = colnames(North_otu)
row.names(AL_900_North_sums) = "AL_900_North"

# %%
AL_1000_North_meta = subset(North_map1, treat == "1000_AL")
AL_1000_North_otu = North_otu[rownames(AL_1000_North_meta), ]
AL_1000_North_sums = rbind.data.frame(colSums(AL_1000_North_otu))
colnames(AL_1000_North_sums) = colnames(North_otu)
row.names(AL_1000_North_sums) = "AL_1000_North"

# %%
AL_1100_North_meta = subset(North_map1, treat == "1100_AL")
AL_1100_North_otu = North_otu[rownames(AL_1100_North_meta), ]
AL_1100_North_sums = rbind.data.frame(colSums(AL_1100_North_otu))
colnames(AL_1100_North_sums) = colnames(North_otu)
row.names(AL_1100_North_sums) = "AL_1100_North"

# %%
AL_1200_North_meta = subset(North_map1, treat == "1200_AL")
AL_1200_North_otu = North_otu[rownames(AL_1200_North_meta), ]
AL_1200_North_sums = rbind.data.frame(colSums(AL_1200_North_otu))
colnames(AL_1200_North_sums) = colnames(North_otu)
row.names(AL_1200_North_sums) = "AL_1200_North"

# %%
AL_1300_North_meta = subset(North_map1, treat == "1300_AL")
AL_1300_North_otu = North_otu[rownames(AL_1300_North_meta), ]
AL_1300_North_sums = rbind.data.frame(colSums(AL_1300_North_otu))
colnames(AL_1300_North_sums) = colnames(North_otu)
row.names(AL_1300_North_sums) = "AL_1300_North"

# %%
AL_1400_North_meta = subset(North_map1, treat == "1400_AL")
AL_1400_North_otu = North_otu[rownames(AL_1400_North_meta), ]
AL_1400_North_sums = rbind.data.frame(colSums(AL_1400_North_otu))
colnames(AL_1400_North_sums) = colnames(North_otu)
row.names(AL_1400_North_sums) = "AL_1400_North"

# %%
AL_1500_North_meta = subset(North_map1, treat == "1500_AL")
AL_1500_North_otu = North_otu[rownames(AL_1500_North_meta), ]
AL_1500_North_sums = rbind.data.frame(colSums(AL_1500_North_otu))
colnames(AL_1500_North_sums) = colnames(North_otu)
row.names(AL_1500_North_sums) = "AL_1500_North"

# %%
AL_1600_North_meta = subset(North_map1, treat == "1600_AL")
AL_1600_North_otu = North_otu[rownames(AL_1600_North_meta), ]
AL_1600_North_sums = rbind.data.frame(colSums(AL_1600_North_otu))
colnames(AL_1600_North_sums) = colnames(North_otu)
row.names(AL_1600_North_sums) = "AL_1600_North"

# %%
AL_1700_North_meta = subset(North_map1, treat == "1700_AL")
AL_1700_North_otu = North_otu[rownames(AL_1700_North_meta), ]
AL_1700_North_sums = rbind.data.frame(colSums(AL_1700_North_otu))
colnames(AL_1700_North_sums) = colnames(North_otu)
row.names(AL_1700_North_sums) = "AL_1700_North"

# %%
AL_1800_North_meta = subset(North_map1, treat == "1800_AL")
AL_1800_North_otu = North_otu[rownames(AL_1800_North_meta), ]
AL_1800_North_sums = rbind.data.frame(colSums(AL_1800_North_otu))
colnames(AL_1800_North_sums) = colnames(North_otu)
row.names(AL_1800_North_sums) = "AL_1800_North"

# %%
AL_1900_North_meta = subset(North_map1, treat == "1900_AL")
AL_1900_North_otu = North_otu[rownames(AL_1900_North_meta), ]
AL_1900_North_sums = rbind.data.frame(colSums(AL_1900_North_otu))
colnames(AL_1900_North_sums) = colnames(North_otu)
row.names(AL_1900_North_sums) = "AL_1900_North"

# %%
AL_2000_North_meta = subset(North_map1, treat == "2000_AL")
AL_2000_North_otu = North_otu[rownames(AL_2000_North_meta), ]
AL_2000_North_sums = rbind.data.frame(colSums(AL_2000_North_otu))
colnames(AL_2000_North_sums) = colnames(North_otu)
row.names(AL_2000_North_sums) = "AL_2000_North"

# %%
AL_2100_North_meta = subset(North_map1, treat == "2100_AL")
AL_2100_North_otu = North_otu[rownames(AL_2100_North_meta), ]
AL_2100_North_sums = rbind.data.frame(colSums(AL_2100_North_otu))
colnames(AL_2100_North_sums) = colnames(North_otu)
row.names(AL_2100_North_sums) = "AL_2100_North"

# %%
AL_2200_North_meta = subset(North_map1, treat == "2200_AL")
AL_2200_North_otu = North_otu[rownames(AL_2200_North_meta), ]
AL_2200_North_sums = rbind.data.frame(colSums(AL_2200_North_otu))
colnames(AL_2200_North_sums) = colnames(North_otu)
row.names(AL_2200_North_sums) = "AL_2200_North"

# %%
AL_2300_North_meta = subset(North_map1, treat == "2300_AL")
AL_2300_North_otu = North_otu[rownames(AL_2300_North_meta), ]
AL_2300_North_sums = rbind.data.frame(colSums(AL_2300_North_otu))
colnames(AL_2300_North_sums) = colnames(North_otu)
row.names(AL_2300_North_sums) = "AL_2300_North"

# %%
AL_2400_North_meta = subset(North_map1, treat == "2400_AL")
AL_2400_North_otu = North_otu[rownames(AL_2400_North_meta), ]
AL_2400_North_sums = rbind.data.frame(colSums(AL_2400_North_otu))
colnames(AL_2400_North_sums) = colnames(North_otu)
row.names(AL_2400_North_sums) = "AL_2400_North"

# %%
AL_North_1 = rbind.data.frame(AL_600_North_sums,AL_700_North_sums,AL_800_North_sums,AL_900_North_sums)
AL_North_1_prime = dfun(AL_North_1)
AL_North_1_prime
# Out:
# $dprime
# AL_600_North AL_700_North AL_800_North AL_900_North
#    0.4314993    0.4218177    0.4215410    0.5420323
#
# $d
# AL_600_North AL_700_North AL_800_North AL_900_North
#    0.5992945    0.5858918    0.5855087    0.7523100
#
# $dmin
# AL_600_North AL_700_North AL_800_North AL_900_North
#  0.001951385  0.001951385  0.001951385  0.001951385
#
# $dmax
# AL_600_North AL_700_North AL_800_North AL_900_North
#     1.386294     1.386294     1.386294     1.386294

# %%
AL_North_2 = rbind.data.frame(AL_1000_North_sums,AL_1100_North_sums,AL_1200_North_sums,AL_1300_North_sums)
AL_North_2_prime = dfun(AL_North_2)
AL_North_2_prime
# Out:
# $dprime
# AL_1000_North AL_1100_North AL_1200_North AL_1300_North
#     0.5761603     0.5197224     0.4833369     0.6742686
#
# $d
# AL_1000_North AL_1100_North AL_1200_North AL_1300_North
#     0.8001325     0.7220800     0.6717595     0.9358143
#
# $dmin
# AL_1000_North AL_1100_North AL_1200_North AL_1300_North
#   0.003314182   0.003314182   0.003314182   0.003314182
#
# $dmax
# AL_1000_North AL_1100_North AL_1200_North AL_1300_North
#      1.386294      1.386294      1.386294      1.386294

# %%
AL_North_3 = rbind.data.frame(AL_1400_North_sums,AL_1500_North_sums,AL_1600_North_sums,AL_1700_North_sums)
AL_North_3_prime = dfun(AL_North_3)
AL_North_3_prime
# Out:
# $dprime
# AL_1400_North AL_1500_North AL_1600_North AL_1700_North
#     0.4588671     0.4043676     0.4194222     0.4109444
#
# $d
# AL_1400_North AL_1500_North AL_1600_North AL_1700_North
#     0.6380244     0.5626635     0.5834808     0.5717578
#
# $dmin
# AL_1400_North AL_1500_North AL_1600_North AL_1700_North
#   0.003510455   0.003510455   0.003510455   0.003510455
#
# $dmax
# AL_1400_North AL_1500_North AL_1600_North AL_1700_North
#      1.386294      1.386294      1.386294      1.386294

# %%
AL_North_4 = rbind.data.frame(AL_1800_North_sums,AL_1900_North_sums,AL_2000_North_sums,AL_2100_North_sums)
AL_North_4_prime = dfun(AL_North_4)
AL_North_4_prime
# Out:
# $dprime
# AL_1800_North AL_1900_North AL_2000_North AL_2100_North
#     0.3402069     0.4217283     0.3690665     0.4778574
#
# $d
# AL_1800_North AL_1900_North AL_2000_North AL_2100_North
#     0.4738403     0.5865795     0.5137514     0.6642027
#
# $dmin
# AL_1800_North AL_1900_North AL_2000_North AL_2100_North
#   0.003354734   0.003354734   0.003354734   0.003354734
#
# $dmax
# AL_1800_North AL_1900_North AL_2000_North AL_2100_North
#      1.386294      1.386294      1.386294      1.386294

# %%
AL_North_5 = rbind.data.frame(AL_2200_North_sums,AL_2300_North_sums,AL_2400_North_sums)
AL_North_5_prime = dfun(AL_North_5)
AL_North_5_prime
# Out:
# $dprime
# AL_2200_North AL_2300_North AL_2400_North
#     0.4734229     0.3250092     0.3362532
#
# $d
# AL_2200_North AL_2300_North AL_2400_North
#     0.5211541     0.3583999     0.3707302
#
# $dmin
# AL_2200_North AL_2300_North AL_2400_North
#   0.001986296   0.001986296   0.001986296
#
# $dmax
# AL_2200_North AL_2300_North AL_2400_North
#      1.098612      1.098612      1.098612

# %%
host_specialization = read.table(file = "host_specialization.txt", header = T)
head(host_specialization)
# Out:
#   host elevation dprime
# 1 EA    600      0.3531488
# 2 EA    700      0.3813264
# 3 EA    800      0.5204497
# 4 EA    900      0.4477860
# 5 EA   1000      0.5631456
# 6 EA   1100      0.4954666

# %%
host_specialization_EA = subset(host_specialization, host == "EA")
host_specialization_AL = subset(host_specialization, host == "AL")

# %%
bestFitM2(data = host_specialization_AL, x = "elevation", y = "dprime")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -38.92257 -35.14481 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -38.92257 -35.14481  line3P  y = ax^2+bx+c
# 1 -38.44148 -35.60816  line2P       y = ax+b
# 4 -38.17407 -35.34075   exp2P y = a*exp(b*x)
# 3 -36.91225 -34.07894   log2P    y=a*ln(x)+b
# 5 -36.64951 -33.81619 power2P      y = a*x^b

# %%
summary(lm(dprime~elevation + I(elevation^2), data = host_specialization_AL))
# Out:
# Call:
# lm(formula = dprime ~ elevation + I(elevation^2), data = host_specialization_AL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.10676 -0.04890 -0.02458  0.04342  0.18662
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.632e-01  1.383e-01   2.626   0.0183 *
# elevation       2.236e-04  2.002e-04   1.117   0.2804
# I(elevation^2) -9.838e-08  6.585e-08  -1.494   0.1546
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0767 on 16 degrees of freedom
# Multiple R-squared:   0.31,	Adjusted R-squared:  0.2237
# F-statistic: 3.594 on 2 and 16 DF,  p-value: 0.0514

# %%
summary(lm(dprime~elevation, data = host_specialization_AL))
# Out:
# Call:
# lm(formula = dprime ~ elevation, data = host_specialization_AL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.08610 -0.05634 -0.02119  0.04735  0.21220
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.550e-01  5.313e-02   10.45 8.13e-09 ***
# elevation   -7.152e-05  3.327e-05   -2.15   0.0463 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07943 on 17 degrees of freedom
# Multiple R-squared:  0.2137,	Adjusted R-squared:  0.1675
# F-statistic: 4.621 on 1 and 17 DF,  p-value: 0.04628

# %%
bestFitM2(data = host_specialization_EA, x = "elevation", y = "dprime")
# Out:
# $BestFitM2
#        AIC       BIC model     formula
# 3 -46.7991 -43.96578 log2P y=a*ln(x)+b
#
# $AllModel
#         AIC       BIC   model        formula
# 3 -46.79910 -43.96578   log2P    y=a*ln(x)+b
# 5 -46.77907 -43.94576 power2P      y = a*x^b
# 1 -46.51242 -43.67910  line2P       y = ax+b
# 4 -46.50836 -43.67504   exp2P y = a*exp(b*x)
# 2 -45.48938 -41.71162  line3P  y = ax^2+bx+c

# %%
summary(lm(dprime~elevation, data = host_specialization_EA))
# Out:
# Call:
# lm(formula = dprime ~ elevation, data = host_specialization_EA)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.113965 -0.032800  0.008167  0.040377  0.105894
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.471e-01  4.296e-02  10.406 8.61e-09 ***
# elevation   1.018e-05  2.690e-05   0.378     0.71
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06423 on 17 degrees of freedom
# Multiple R-squared:  0.008353,	Adjusted R-squared:  -0.04998
# F-statistic: 0.1432 on 1 and 17 DF,  p-value: 0.7098

# %%
summary(lm(dprime~elevation + I(elevation^2), data = host_specialization_EA))
# Out:
# Call:
# lm(formula = dprime ~ elevation + I(elevation^2), data = host_specialization_EA)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.11651 -0.04325  0.01122  0.03020  0.10335
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.478e-01  1.163e-01   2.990  0.00867 **
# elevation       1.629e-04  1.684e-04   0.967  0.34776
# I(elevation^2) -5.091e-08  5.540e-08  -0.919  0.37184
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06453 on 16 degrees of freedom
# Multiple R-squared:  0.05805,	Adjusted R-squared:  -0.05969
# F-statistic: 0.4931 on 2 and 16 DF,  p-value: 0.6197

# %%
host_specialization_1 = read.table(file = "host_specialization_1.txt", header = T)
ggplot(data = host_specialization_1 , aes(x = elevation, y = EA_dprime)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_dprime), color = "#1e90ff") +
  geom_smooth(method = "lm", color = "#1e90ff", se = FALSE,
              aes(elevation, AL_dprime)) +
  labs(x = "Elevation(m)" , y = "Host specialisation" ) +
  theme_bw()
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Rhizosphere fungal co-occurrence

# %% [markdown]
# #### To improve the computation speed, we used a C++ implementation Fastspar for SparCC algorithm

# %%
North_cor = read.table(file = "Network/Fastspar//North_median_cor.tsv", header = T)
North_pval = read.table(file = "Network/Fastspar/North_pval.tsv", header = T)

# %%
map_North = read.table(file = "map_North.txt",header =T)
map_North1 = unite(map_North, "treat", elevation, host, remove = FALSE)
head(map_North1)
# Out:
#         treat  elevation host
# sample1 600_EA 600       EA
# sample2 600_EA 600       EA
# sample3 600_EA 600       EA
# sample4 600_EA 600       EA
# sample5 600_EA 600       EA
# sample6 600_AL 600       AL

# %%
feature_occur_10 = read.table(file = "Network/feature_occur_10.txt", header = T)
head(feature_occur_10)
# Out:
#                                  sample1 sample2 sample3 sample4 sample5
# 6b9d995dfc0b8c790f9bc6add0cd1c11    0       0    4302       0       0
# b23c0873c3603627c7205163f3df2298    0       0       0       0      10
# 3d2258d3cda1b5305d5d1acc7b4df677    0       0       0       0       0
# a82534894a552a37b7bf6e9fe5baddf5 3264    5791    1746    3378     145
# 7a47974ec8aff2c1e5383f2f6e177bb5    2      33      53       5      34
# de0bb5730f204f95bedb66ea7217438d 1470      63     343     475    1320
#                                  sample6 sample7 sample8 sample9 sample10 ⋯
# 6b9d995dfc0b8c790f9bc6add0cd1c11   49       7      11       0       0     ⋯
# b23c0873c3603627c7205163f3df2298    0      88       0       0       0     ⋯
# 3d2258d3cda1b5305d5d1acc7b4df677    0      48       0       0      35     ⋯
# a82534894a552a37b7bf6e9fe5baddf5  399    2328    1897      97    3783     ⋯
# 7a47974ec8aff2c1e5383f2f6e177bb5    0       8       6       0      28     ⋯
# ...

# %% [markdown]
# ##### extract the correlation for each sample

# %%
EA_600_map = subset(map_North1, treat == "600_EA")
feature_occur_10_EA600 = feature_occur_10[,rownames(EA_600_map)]
feature_occur_10_EA600 = feature_occur_10_EA600[which(rowSums(feature_occur_10_EA600)>0),]
write.table(feature_occur_10_EA600, file = "Network/Fastspar/EA600.txt", sep = "\t")

# %%
EA_700_map = subset(map_North1, treat == "700_EA")
feature_occur_10_EA700 = feature_occur_10[,rownames(EA_700_map)]
feature_occur_10_EA700 = feature_occur_10_EA700[which(rowSums(feature_occur_10_EA700)>0),]
write.table(feature_occur_10_EA700, file = "Network/Fastspar/EA700.txt", sep = "\t")

# %%
EA_800_map = subset(map_North1, treat == "800_EA")
feature_occur_10_EA800 = feature_occur_10[,rownames(EA_800_map)]
feature_occur_10_EA800 = feature_occur_10_EA800[which(rowSums(feature_occur_10_EA800)>0),]
write.table(feature_occur_10_EA800, file = "Network/Fastspar/EA800.txt", sep = "\t")

# %%
EA_900_map = subset(map_North1, treat == "900_EA")
feature_occur_10_EA900 = feature_occur_10[,rownames(EA_900_map)]
feature_occur_10_EA900 = feature_occur_10_EA900[which(rowSums(feature_occur_10_EA900)>0),]
write.table(feature_occur_10_EA900, file = "Network/Fastspar/EA900.txt", sep = "\t")

# %%
EA_1000_map = subset(map_North1, treat == "1000_EA")
feature_occur_10_EA1000 = feature_occur_10[,rownames(EA_1000_map)]
feature_occur_10_EA1000 = feature_occur_10_EA1000[which(rowSums(feature_occur_10_EA1000)>0),]
write.table(feature_occur_10_EA1000, file = "Network/Fastspar/EA1000.txt", sep = "\t")

# %%
EA_1100_map = subset(map_North1, treat == "1100_EA")
feature_occur_10_EA1100 = feature_occur_10[,rownames(EA_1100_map)]
feature_occur_10_EA1100 = feature_occur_10_EA1100[which(rowSums(feature_occur_10_EA1100)>0),]
write.table(feature_occur_10_EA1100, file = "Network/Fastspar/EA1100.txt", sep = "\t")

# %%
EA_1200_map = subset(map_North1, treat == "1200_EA")
feature_occur_10_EA1200 = feature_occur_10[,rownames(EA_1200_map)]
feature_occur_10_EA1200 = feature_occur_10_EA1200[which(rowSums(feature_occur_10_EA1200)>0),]
write.table(feature_occur_10_EA1200, file = "Network/Fastspar/EA1200.txt", sep = "\t")

# %%
EA_1300_map = subset(map_North1, treat == "1300_EA")
feature_occur_10_EA1300 = feature_occur_10[,rownames(EA_1300_map)]
feature_occur_10_EA1300 = feature_occur_10_EA1300[which(rowSums(feature_occur_10_EA1300)>0),]
write.table(feature_occur_10_EA1300, file = "Network/Fastspar/EA1300.txt", sep = "\t")

# %%
EA_1400_map = subset(map_North1, treat == "1400_EA")
feature_occur_10_EA1400 = feature_occur_10[,rownames(EA_1400_map)]
feature_occur_10_EA1400 = feature_occur_10_EA1400[which(rowSums(feature_occur_10_EA1400)>0),]
write.table(feature_occur_10_EA1400, file = "Network/Fastspar/EA1400.txt", sep = "\t")

# %%
EA_1500_map = subset(map_North1, treat == "1500_EA")
feature_occur_10_EA1500 = feature_occur_10[,rownames(EA_1500_map)]
feature_occur_10_EA1500 = feature_occur_10_EA1500[which(rowSums(feature_occur_10_EA1500)>0),]
write.table(feature_occur_10_EA1500, file = "Network/Fastspar/EA1500.txt", sep = "\t")

# %%
EA_1600_map = subset(map_North1, treat == "1600_EA")
feature_occur_10_EA1600 = feature_occur_10[,rownames(EA_1600_map)]
feature_occur_10_EA1600 = feature_occur_10_EA1600[which(rowSums(feature_occur_10_EA1600)>0),]
write.table(feature_occur_10_EA1600, file = "Network/Fastspar/EA1600.txt", sep = "\t")

# %%
EA_1700_map = subset(map_North1, treat == "1700_EA")
feature_occur_10_EA1700 = feature_occur_10[,rownames(EA_1700_map)]
feature_occur_10_EA1700 = feature_occur_10_EA1700[which(rowSums(feature_occur_10_EA1700)>0),]
write.table(feature_occur_10_EA1700, file = "Network/Fastspar/EA1700.txt", sep = "\t")

# %%
EA_1800_map = subset(map_North1, treat == "1800_EA")
feature_occur_10_EA1800 = feature_occur_10[,rownames(EA_1800_map)]
feature_occur_10_EA1800 = feature_occur_10_EA1800[which(rowSums(feature_occur_10_EA1800)>0),]
write.table(feature_occur_10_EA1800, file = "Network/Fastspar/EA1800.txt", sep = "\t")

# %%
EA_1900_map = subset(map_North1, treat == "1900_EA")
feature_occur_10_EA1900 = feature_occur_10[,rownames(EA_1900_map)]
feature_occur_10_EA1900 = feature_occur_10_EA1900[which(rowSums(feature_occur_10_EA1900)>0),]
write.table(feature_occur_10_EA1900, file = "Network/Fastspar/EA1900.txt", sep = "\t")

# %%
EA_2000_map = subset(map_North1, treat == "2000_EA")
feature_occur_10_EA2000 = feature_occur_10[,rownames(EA_2000_map)]
feature_occur_10_EA2000 = feature_occur_10_EA2000[which(rowSums(feature_occur_10_EA2000)>0),]
write.table(feature_occur_10_EA2000, file = "Network/Fastspar/EA2000.txt", sep = "\t")

# %%
EA_2100_map = subset(map_North1, treat == "2100_EA")
feature_occur_10_EA2100 = feature_occur_10[,rownames(EA_2100_map)]
feature_occur_10_EA2100 = feature_occur_10_EA2100[which(rowSums(feature_occur_10_EA2100)>0),]
write.table(feature_occur_10_EA2100, file = "Network/Fastspar/EA2100.txt", sep = "\t")

# %%
EA_2200_map = subset(map_North1, treat == "2200_EA")
feature_occur_10_EA2200 = feature_occur_10[,rownames(EA_2200_map)]
feature_occur_10_EA2200 = feature_occur_10_EA2200[which(rowSums(feature_occur_10_EA2200)>0),]
write.table(feature_occur_10_EA2200, file = "Network/Fastspar/EA2200.txt", sep = "\t")

# %%
EA_2300_map = subset(map_North1, treat == "2300_EA")
feature_occur_10_EA2300 = feature_occur_10[,rownames(EA_2300_map)]
feature_occur_10_EA2300 = feature_occur_10_EA2300[which(rowSums(feature_occur_10_EA2300)>0),]
write.table(feature_occur_10_EA2300, file = "Network/Fastspar/EA2300.txt", sep = "\t")

# %%
EA_2400_map = subset(map_North1, treat == "2400_EA")
feature_occur_10_EA2400 = feature_occur_10[,rownames(EA_2400_map)]
feature_occur_10_EA2400 = feature_occur_10_EA2400[which(rowSums(feature_occur_10_EA2400)>0),]
write.table(feature_occur_10_EA2400, file = "Network/Fastspar/EA2400.txt", sep = "\t")

# %%
AL_600_map = subset(map_North1, treat == "600_AL")
feature_occur_10_AL600 = feature_occur_10[,rownames(AL_600_map)]
feature_occur_10_AL600 = feature_occur_10_AL600[which(rowSums(feature_occur_10_AL600)>0),]
write.table(feature_occur_10_AL600, file = "Network/Fastspar/AL600.txt", sep = "\t")

# %%
AL_700_map = subset(map_North1, treat == "700_AL")
feature_occur_10_AL700 = feature_occur_10[,rownames(AL_700_map)]
feature_occur_10_AL700 = feature_occur_10_AL700[which(rowSums(feature_occur_10_AL700)>0),]
write.table(feature_occur_10_AL700, file = "Network/Fastspar/AL700.txt", sep = "\t")

# %%
AL_800_map = subset(map_North1, treat == "800_AL")
feature_occur_10_AL800 = feature_occur_10[,rownames(AL_800_map)]
feature_occur_10_AL800 = feature_occur_10_AL800[which(rowSums(feature_occur_10_AL800)>0),]
write.table(feature_occur_10_AL800, file = "Network/Fastspar/AL800.txt", sep = "\t")

# %%
AL_900_map = subset(map_North1, treat == "900_AL")
feature_occur_10_AL900 = feature_occur_10[,rownames(AL_900_map)]
feature_occur_10_AL900 = feature_occur_10_AL900[which(rowSums(feature_occur_10_AL900)>0),]
write.table(feature_occur_10_AL900, file = "Network/Fastspar/AL900.txt", sep = "\t")

# %%
AL_1000_map = subset(map_North1, treat == "1000_AL")
feature_occur_10_AL1000 = feature_occur_10[,rownames(AL_1000_map)]
feature_occur_10_AL1000 = feature_occur_10_AL1000[which(rowSums(feature_occur_10_AL1000)>0),]
write.table(feature_occur_10_AL1000, file = "Network/Fastspar/AL1000.txt", sep = "\t")

# %%
AL_1100_map = subset(map_North1, treat == "1100_AL")
feature_occur_10_AL1100 = feature_occur_10[,rownames(AL_1100_map)]
feature_occur_10_AL1100 = feature_occur_10_AL1100[which(rowSums(feature_occur_10_AL1100)>0),]
write.table(feature_occur_10_AL1100, file = "Network/Fastspar/AL1100.txt", sep = "\t")

# %%
AL_1200_map = subset(map_North1, treat == "1200_AL")
feature_occur_10_AL1200 = feature_occur_10[,rownames(AL_1200_map)]
feature_occur_10_AL1200 = feature_occur_10_AL1200[which(rowSums(feature_occur_10_AL1200)>0),]
write.table(feature_occur_10_AL1200, file = "Network/Fastspar/AL1200.txt", sep = "\t")

# %%
AL_1300_map = subset(map_North1, treat == "1300_AL")
feature_occur_10_AL1300 = feature_occur_10[,rownames(AL_1300_map)]
feature_occur_10_AL1300 = feature_occur_10_AL1300[which(rowSums(feature_occur_10_AL1300)>0),]
write.table(feature_occur_10_AL1300, file = "Network/Fastspar/AL1300.txt", sep = "\t")

# %%
AL_1400_map = subset(map_North1, treat == "1400_AL")
feature_occur_10_AL1400 = feature_occur_10[,rownames(AL_1400_map)]
feature_occur_10_AL1400 = feature_occur_10_AL1400[which(rowSums(feature_occur_10_AL1400)>0),]
write.table(feature_occur_10_AL1400, file = "Network/Fastspar/AL1400.txt", sep = "\t")

# %%
AL_1500_map = subset(map_North1, treat == "1500_AL")
feature_occur_10_AL1500 = feature_occur_10[,rownames(AL_1500_map)]
feature_occur_10_AL1500 = feature_occur_10_AL1500[which(rowSums(feature_occur_10_AL1500)>0),]
write.table(feature_occur_10_AL1500, file = "Network/Fastspar/AL1500.txt", sep = "\t")

# %%
AL_1600_map = subset(map_North1, treat == "1600_AL")
feature_occur_10_AL1600 = feature_occur_10[,rownames(AL_1600_map)]
feature_occur_10_AL1600 = feature_occur_10_AL1600[which(rowSums(feature_occur_10_AL1600)>0),]
write.table(feature_occur_10_AL1600, file = "Network/Fastspar/AL1600.txt", sep = "\t")

# %%
AL_1700_map = subset(map_North1, treat == "1700_AL")
feature_occur_10_AL1700 = feature_occur_10[,rownames(AL_1700_map)]
feature_occur_10_AL1700 = feature_occur_10_AL1700[which(rowSums(feature_occur_10_AL1700)>0),]
write.table(feature_occur_10_AL1700, file = "Network/Fastspar/AL1700.txt", sep = "\t")

# %%
AL_1800_map = subset(map_North1, treat == "1800_AL")
feature_occur_10_AL1800 = feature_occur_10[,rownames(AL_1800_map)]
feature_occur_10_AL1800 = feature_occur_10_AL1800[which(rowSums(feature_occur_10_AL1800)>0),]
write.table(feature_occur_10_AL1800, file = "Network/Fastspar/AL1800.txt", sep = "\t")

# %%
AL_1900_map = subset(map_North1, treat == "1900_AL")
feature_occur_10_AL1900 = feature_occur_10[,rownames(AL_1900_map)]
feature_occur_10_AL1900 = feature_occur_10_AL1900[which(rowSums(feature_occur_10_AL1900)>0),]
write.table(feature_occur_10_AL1900, file = "Network/Fastspar/AL1900.txt", sep = "\t")

# %%
AL_2000_map = subset(map_North1, treat == "2000_AL")
feature_occur_10_AL2000 = feature_occur_10[,rownames(AL_2000_map)]
feature_occur_10_AL2000 = feature_occur_10_AL2000[which(rowSums(feature_occur_10_AL2000)>0),]
write.table(feature_occur_10_AL2000, file = "Network/Fastspar/AL2000.txt", sep = "\t")

# %%
AL_2100_map = subset(map_North1, treat == "2100_AL")
feature_occur_10_AL2100 = feature_occur_10[,rownames(AL_2100_map)]
feature_occur_10_AL2100 = feature_occur_10_AL2100[which(rowSums(feature_occur_10_AL2100)>0),]
write.table(feature_occur_10_AL2100, file = "Network/Fastspar/AL2100.txt", sep = "\t")

# %%
AL_2200_map = subset(map_North1, treat == "2200_AL")
feature_occur_10_AL2200 = feature_occur_10[,rownames(AL_2200_map)]
feature_occur_10_AL2200 = feature_occur_10_AL2200[which(rowSums(feature_occur_10_AL2200)>0),]
write.table(feature_occur_10_AL2200, file = "Network/Fastspar/AL2200.txt", sep = "\t")

# %%
AL_2300_map = subset(map_North1, treat == "2300_AL")
feature_occur_10_AL2300 = feature_occur_10[,rownames(AL_2300_map)]
feature_occur_10_AL2300 = feature_occur_10_AL2300[which(rowSums(feature_occur_10_AL2300)>0),]
write.table(feature_occur_10_AL2300, file = "Network/Fastspar/AL2300.txt", sep = "\t")

# %%
AL_2400_map = subset(map_North1, treat == "2400_AL")
feature_occur_10_AL2400 = feature_occur_10[,rownames(AL_2400_map)]
feature_occur_10_AL2400 = feature_occur_10_AL2400[which(rowSums(feature_occur_10_AL2400)>0),]
write.table(feature_occur_10_AL2400, file = "Network/Fastspar/AL2400.txt", sep = "\t")

# %% [markdown]
# ##### extract the topology parameters

# %%
library(igraph)
# Out:
# Warning message:
# “package ‘igraph’ was built under R version 4.0.5”
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:bipartite’:
#
#     strength
#
#
# The following objects are masked from ‘package:sna’:
#
#     betweenness, bonpow, closeness, components, degree, dyad.census,
#     evcent, hierarchy, is.connected, neighborhood, triad.census
#
#
# The following objects are masked from ‘package:network’:
#
#     %c%, %s%, add.edges, add.vertices, delete.edges, delete.vertices,
#     get.edge.attribute, get.edges, get.vertex.attribute, is.bipartite,
#     is.directed, list.edge.attributes, list.vertex.attributes,
#     set.edge.attribute, set.vertex.attribute
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:vegan’:
#
#     diversity
#
#
# The following object is masked from ‘package:permute’:
#
#     permute
#
#
# The following objects are masked from ‘package:stats’:
#
# ...

# %%
AL600 = read.table(file = "Network/Fastspar/AL600.txt", header =T)
head(AL600)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL600  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 AL600  3d2258d3cda1b5305d5d1acc7b4df677
# 3 c1ed637b068ec1ae35761ae587061e72 AL600  3d2258d3cda1b5305d5d1acc7b4df677
# 4 38f440bd83eb3f9e3064522f3d0db449 AL600  3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c AL600  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 3cb128716ea20130263a04106234e436 AL600  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 AL600  0.001 0.4065 0.4065
# 2 AL600  0.001 0.4235 0.4235
# 3 AL600  0.001 0.4074 0.4074
# 4 AL600  0.001 0.4028 0.4028
# 5 AL600  0.001 0.4525 0.4525
# 6 AL600  0.001 0.4539 0.4539

# %%
AL600_1 = subset(AL600, cor < 0)
length(AL600_1$cor)/length(AL600$cor)
1-length(AL600_1$cor)/length(AL600$cor)
# Out:
# [1] 0.2163522
# [1] 0.7836478

# %%
AL600_2 = AL600[,c(1,3)]
AL600_net = graph_from_edgelist(as.matrix(AL600_2), directed = FALSE)
length(V(AL600_net))
length(E(AL600_net))
# average degree
mean(degree(AL600_net))
# average betweenness
mean(betweenness(AL600_net))
# clustering coefficient
transitivity(AL600_net)
# modularity
AL600_m = cluster_fast_greedy(AL600_net)
modularity(AL600_net, membership(AL600_m))
# Out:
# [1] 128
# [1] 795
# [1] 12.42188
# [1] 75.5
# [1] 0.4840312
# [1] 0.2029089

# %%
AL700 = read.table(file = "Network/Fastspar/AL700.txt", header =T)
head(AL700)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL700  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 AL700  3d2258d3cda1b5305d5d1acc7b4df677
# 3 c1ed637b068ec1ae35761ae587061e72 AL700  3d2258d3cda1b5305d5d1acc7b4df677
# 4 38f440bd83eb3f9e3064522f3d0db449 AL700  3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c AL700  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 3cb128716ea20130263a04106234e436 AL700  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 AL700  0.001 0.4065 0.4065
# 2 AL700  0.001 0.4235 0.4235
# 3 AL700  0.001 0.4074 0.4074
# 4 AL700  0.001 0.4028 0.4028
# 5 AL700  0.001 0.4525 0.4525
# 6 AL700  0.001 0.4539 0.4539

# %%
AL700_1 = subset(AL700, cor < 0)
length(AL700_1$cor)/length(AL700$cor)
1-length(AL700_1$cor)/length(AL700$cor)
# Out:
# [1] 0.213217
# [1] 0.786783

# %%
AL700_2 = AL700[,c(1,3)]
AL700_net = graph_from_edgelist(as.matrix(AL700_2), directed = FALSE)
length(V(AL700_net))
length(E(AL700_net))
# average degree
mean(degree(AL700_net))
# average betweenness
mean(betweenness(AL700_net))
# clustering coefficient
transitivity(AL700_net)
# modularity
AL700_m = cluster_fast_greedy(AL700_net)
modularity(AL700_net, membership(AL700_m))
# Out:
# [1] 130
# [1] 802
# [1] 12.33846
# [1] 67.40769
# [1] 0.4841088
# [1] 0.2014672

# %%
AL800 = read.table(file = "Network/Fastspar/AL800.txt", header =T)
head(AL800)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL800  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 AL800  3d2258d3cda1b5305d5d1acc7b4df677
# 3 c1ed637b068ec1ae35761ae587061e72 AL800  3d2258d3cda1b5305d5d1acc7b4df677
# 4 38f440bd83eb3f9e3064522f3d0db449 AL800  3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c AL800  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 3cb128716ea20130263a04106234e436 AL800  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 AL800  0.001 0.4065 0.4065
# 2 AL800  0.001 0.4235 0.4235
# 3 AL800  0.001 0.4074 0.4074
# 4 AL800  0.001 0.4028 0.4028
# 5 AL800  0.001 0.4525 0.4525
# 6 AL800  0.001 0.4539 0.4539

# %%
AL800_1 = subset(AL800, cor < 0)
length(AL800_1$cor)/length(AL800$cor)
1-length(AL800_1$cor)/length(AL800$cor)
# Out:
# [1] 0.2485549
# [1] 0.7514451

# %%
AL800_2 = AL800[,c(1,3)]
AL800_net = graph_from_edgelist(as.matrix(AL800_2), directed = FALSE)
length(V(AL800_net))
length(E(AL800_net))
# average degree
mean(degree(AL800_net))
# average betweenness
mean(betweenness(AL800_net))
# clustering coefficient
transitivity(AL800_net)
# modularity
AL800_m = cluster_fast_greedy(AL800_net)
modularity(AL800_net, membership(AL800_m))
# Out:
# [1] 139
# [1] 865
# [1] 12.44604
# [1] 76.1295
# [1] 0.4659297
# [1] 0.2132079

# %%
AL900 = read.table(file = "Network/Fastspar/AL900.txt", header =T)
head(AL900)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL900  7a47974ec8aff2c1e5383f2f6e177bb5
# 2 3cb128716ea20130263a04106234e436 AL900  7a47974ec8aff2c1e5383f2f6e177bb5
# 3 7e6dbf367068c046b28806cc543ea1e1 AL900  7a47974ec8aff2c1e5383f2f6e177bb5
# 4 3eff2d8a1ba50dc876eafc3d5e5579f8 AL900  7a47974ec8aff2c1e5383f2f6e177bb5
# 5 38bb5dd7980ee82cf4692388b3d09469 AL900  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 1d303a84e2c1f6add44e721a50800f69 AL900  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 AL900  0.001 0.4525 0.4525
# 2 AL900  0.001 0.4539 0.4539
# 3 AL900  0.001 0.4818 0.4818
# 4 AL900  0.001 0.4718 0.4718
# 5 AL900  0.001 0.5997 0.5997
# 6 AL900  0.001 0.4045 0.4045

# %%
AL900_1 = subset(AL900, cor < 0)
length(AL900_1$cor)/length(AL900$cor)
1-length(AL900_1$cor)/length(AL900$cor)
# Out:
# [1] 0.2993865
# [1] 0.7006135

# %%
AL900_2 = AL900[,c(1,3)]
AL900_net = graph_from_edgelist(as.matrix(AL900_2), directed = FALSE)
length(V(AL900_net))
length(E(AL900_net))
# average degree
mean(degree(AL900_net))
# average betweenness
mean(betweenness(AL900_net))
# clustering coefficient
transitivity(AL900_net)
# modularity
AL900_m = cluster_fast_greedy(AL900_net)
modularity(AL900_net, membership(AL900_m))
# Out:
# [1] 125
# [1] 815
# [1] 13.04
# [1] 77.928
# [1] 0.5099651
# [1] 0.1983989

# %%
AL1000 = read.table(file = "Network/Fastspar/AL1000.txt", header =T)
head(AL1000)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL1000 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 AL1000 3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 AL1000 3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 AL1000 3d2258d3cda1b5305d5d1acc7b4df677
# 5 38f440bd83eb3f9e3064522f3d0db449 AL1000 3d2258d3cda1b5305d5d1acc7b4df677
# 6 aac9c2855db08f8b8c6eda943aebd77c AL1000 7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor     abscor
# 1 AL1000 0.001  0.4065 0.4065
# 2 AL1000 0.001  0.4235 0.4235
# 3 AL1000 0.001 -0.4704 0.4704
# 4 AL1000 0.001  0.4074 0.4074
# 5 AL1000 0.001  0.4028 0.4028
# 6 AL1000 0.001  0.4525 0.4525

# %%
AL1000_1 = subset(AL1000, cor < 0)
length(AL1000_1$cor)/length(AL1000$cor)
1-length(AL1000_1$cor)/length(AL1000$cor)
# Out:
# [1] 0.3716679
# [1] 0.6283321

# %%
AL1000_2 = AL1000[,c(1,3)]
AL1000_net = graph_from_edgelist(as.matrix(AL1000_2), directed = FALSE)
length(V(AL1000_net))
length(E(AL1000_net))
# average degree
mean(degree(AL1000_net))
# average betweenness
mean(betweenness(AL1000_net))
# clustering coefficient
transitivity(AL1000_net)
# modularity
AL1000_m = cluster_fast_greedy(AL1000_net)
modularity(AL1000_net, membership(AL1000_m))
# Out:
# [1] 172
# [1] 1313
# [1] 15.26744
# [1] 107.9477
# [1] 0.4909125
# [1] 0.2090188

# %%
AL1100 = read.table(file = "Network/Fastspar/AL1100.txt", header =T)
head(AL1100)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL1100 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 AL1100 3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 AL1100 3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 AL1100 3d2258d3cda1b5305d5d1acc7b4df677
# 5 38f440bd83eb3f9e3064522f3d0db449 AL1100 3d2258d3cda1b5305d5d1acc7b4df677
# 6 aac9c2855db08f8b8c6eda943aebd77c AL1100 79697d6bda362d5e6b2a79a4a1d91034
#   treat1 pval  cor     abscor
# 1 AL1100 0.001  0.4065 0.4065
# 2 AL1100 0.001  0.4235 0.4235
# 3 AL1100 0.001 -0.4704 0.4704
# 4 AL1100 0.001  0.4074 0.4074
# 5 AL1100 0.001  0.4028 0.4028
# 6 AL1100 0.001  0.4292 0.4292

# %%
AL1100_1 = subset(AL1100, cor < 0)
length(AL1100_1$cor)/length(AL1100$cor)
1-length(AL1100_1$cor)/length(AL1100$cor)
# Out:
# [1] 0.3743455
# [1] 0.6256545

# %%
AL1100_2 = AL1100[,c(1,3)]
AL1100_net = graph_from_edgelist(as.matrix(AL1100_2), directed = FALSE)
length(V(AL1100_net))
length(E(AL1100_net))
# average degree
mean(degree(AL1100_net))
# average betweenness
mean(betweenness(AL1100_net))
# clustering coefficient
transitivity(AL1100_net)
# modularity
AL1100_m = cluster_fast_greedy(AL1100_net)
modularity(AL1100_net, membership(AL1100_m))
# Out:
# [1] 161
# [1] 1146
# [1] 14.23602
# [1] 92.86335
# [1] 0.4834406
# [1] 0.1977129

# %%
AL1200 = read.table(file = "Network/Fastspar/AL1200.txt", header =T)
head(AL1200)
# Out:
#   ID2                              treat2 ID1
# 1 3f06c7bc691bbb0332b9ceac51b62666 AL1200 3d2258d3cda1b5305d5d1acc7b4df677
# 2 844e647bddb234e7ebef6630b017b072 AL1200 3d2258d3cda1b5305d5d1acc7b4df677
# 3 c1ed637b068ec1ae35761ae587061e72 AL1200 3d2258d3cda1b5305d5d1acc7b4df677
# 4 38f440bd83eb3f9e3064522f3d0db449 AL1200 3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c AL1200 79697d6bda362d5e6b2a79a4a1d91034
# 6 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1200 79697d6bda362d5e6b2a79a4a1d91034
#   treat1 pval  cor     abscor
# 1 AL1200 0.001  0.4235 0.4235
# 2 AL1200 0.001 -0.4704 0.4704
# 3 AL1200 0.001  0.4074 0.4074
# 4 AL1200 0.001  0.4028 0.4028
# 5 AL1200 0.001  0.4292 0.4292
# 6 AL1200 0.001  0.4132 0.4132

# %%
AL1200_1 = subset(AL1200, cor < 0)
length(AL1200_1$cor)/length(AL1200$cor)
1-length(AL1200_1$cor)/length(AL1200$cor)
# Out:
# [1] 0.4203954
# [1] 0.5796046

# %%
AL1200_2 = AL1200[,c(1,3)]
AL1200_net = graph_from_edgelist(as.matrix(AL1200_2), directed = FALSE)
length(V(AL1200_net))
length(E(AL1200_net))
# average degree
mean(degree(AL1200_net))
# average betweenness
mean(betweenness(AL1200_net))
# clustering coefficient
transitivity(AL1200_net)
# modularity
AL1200_m = cluster_fast_greedy(AL1200_net)
modularity(AL1200_net, membership(AL1200_m))
# Out:
# [1] 149
# [1] 961
# [1] 12.89933
# [1] 85.49664
# [1] 0.5357709
# [1] 0.1912712

# %%
AL1300 = read.table(file = "Network/Fastspar/AL1300.txt", header = T)
head(AL1300)
# Out:
#   ID2                              treat2 ID1
# 1 844e647bddb234e7ebef6630b017b072 AL1300 3d2258d3cda1b5305d5d1acc7b4df677
# 2 aac9c2855db08f8b8c6eda943aebd77c AL1300 79697d6bda362d5e6b2a79a4a1d91034
# 3 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1300 79697d6bda362d5e6b2a79a4a1d91034
# 4 4b9801fee1dbae8635b903d25f5ac16e AL1300 79697d6bda362d5e6b2a79a4a1d91034
# 5 7f098bf95212dc6a706bbad6ad44a306 AL1300 79697d6bda362d5e6b2a79a4a1d91034
# 6 65bb0fbfd950451626807f4dd07771fe AL1300 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL1300 0.001 -0.4704 0.4704
# 2 AL1300 0.001  0.4292 0.4292
# 3 AL1300 0.001  0.4132 0.4132
# 4 AL1300 0.001  0.4519 0.4519
# 5 AL1300 0.001  0.4495 0.4495
# 6 AL1300 0.001  0.6059 0.6059

# %%
AL1300_1 = subset(AL1300, cor < 0)
length(AL1300_1$cor)/length(AL1300$cor)
1-length(AL1300_1$cor)/length(AL1300$cor)
# Out:
# [1] 0.4170338
# [1] 0.5829662

# %%
AL1300_2 = AL1300[,c(1,3)]
AL1300_net = graph_from_edgelist(as.matrix(AL1300_2), directed = FALSE)
length(V(AL1300_net))
length(E(AL1300_net))
# average degree
mean(degree(AL1300_net))
# average betweenness
mean(betweenness(AL1300_net))
# clustering coefficient
transitivity(AL1300_net)
# modularity
AL1300_m = cluster_fast_greedy(AL1300_net)
modularity(AL1300_net, membership(AL1300_m))
# Out:
# [1] 114
# [1] 681
# [1] 11.94737
# [1] 73.85965
# [1] 0.5134865
# [1] 0.184056

# %%
AL1400 = read.table(file = "Network/Fastspar/AL1400.txt", header =T)
head(AL1400)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL1400 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c AL1400 79697d6bda362d5e6b2a79a4a1d91034
# 3 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1400 79697d6bda362d5e6b2a79a4a1d91034
# 4 4b9801fee1dbae8635b903d25f5ac16e AL1400 79697d6bda362d5e6b2a79a4a1d91034
# 5 7f098bf95212dc6a706bbad6ad44a306 AL1400 79697d6bda362d5e6b2a79a4a1d91034
# 6 65bb0fbfd950451626807f4dd07771fe AL1400 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 AL1400 0.001 0.4065 0.4065
# 2 AL1400 0.001 0.4292 0.4292
# 3 AL1400 0.001 0.4132 0.4132
# 4 AL1400 0.001 0.4519 0.4519
# 5 AL1400 0.001 0.4495 0.4495
# 6 AL1400 0.001 0.6059 0.6059

# %%
AL1400_1 = subset(AL1400, cor < 0)
length(AL1400_1$cor)/length(AL1400$cor)
1-length(AL1400_1$cor)/length(AL1400$cor)
# Out:
# [1] 0.4158416
# [1] 0.5841584

# %%
AL1400_2 = AL1400[,c(1,3)]
AL1400_net = graph_from_edgelist(as.matrix(AL1400_2), directed = FALSE)
length(V(AL1400_net))
length(E(AL1400_net))
# average degree
mean(degree(AL1400_net))
# average betweenness
mean(betweenness(AL1400_net))
# clustering coefficient
transitivity(AL1400_net)
# modularity
AL1400_m = cluster_fast_greedy(AL1400_net)
modularity(AL1400_net, membership(AL1400_m))
# Out:
# [1] 159
# [1] 1010
# [1] 12.7044
# [1] 89.03145
# [1] 0.5102215
# [1] 0.1853549

# %%
AL1500 = read.table(file = "Network/Fastspar/AL1500.txt", header =T)
head(AL1500)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL1500 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c AL1500 7a47974ec8aff2c1e5383f2f6e177bb5
# 3 3cb128716ea20130263a04106234e436 AL1500 7a47974ec8aff2c1e5383f2f6e177bb5
# 4 7e6dbf367068c046b28806cc543ea1e1 AL1500 7a47974ec8aff2c1e5383f2f6e177bb5
# 5 22df7ae850b69bc22e975cf243ef9a9a AL1500 7a47974ec8aff2c1e5383f2f6e177bb5
# 6 8ee44c2135047317811efa7f11a379ce AL1500 7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor     abscor
# 1 AL1500 0.001  0.4065 0.4065
# 2 AL1500 0.001  0.4525 0.4525
# 3 AL1500 0.001  0.4539 0.4539
# 4 AL1500 0.001  0.4818 0.4818
# 5 AL1500 0.001 -0.4249 0.4249
# 6 AL1500 0.001 -0.4217 0.4217

# %%
AL1500_1 = subset(AL1500, cor < 0)
length(AL1500_1$cor)/length(AL1500$cor)
1-length(AL1500_1$cor)/length(AL1500$cor)
# Out:
# [1] 0.4079229
# [1] 0.5920771

# %%
AL1500_2 = AL1500[,c(1,3)]
AL1500_net = graph_from_edgelist(as.matrix(AL1500_2), directed = FALSE)
length(V(AL1500_net))
length(E(AL1500_net))
# average degree
mean(degree(AL1500_net))
# average betweenness
mean(betweenness(AL1500_net))
# clustering coefficient
transitivity(AL1500_net)
# modularity
AL1500_m = cluster_fast_greedy(AL1500_net)
modularity(AL1500_net, membership(AL1500_m))
# Out:
# [1] 153
# [1] 934
# [1] 12.20915
# [1] 95.35948
# [1] 0.5182244
# [1] 0.2119278

# %%
AL1600 = read.table(file = "Network/Fastspar/AL1600.txt", header =T)
head(AL1600)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL1600 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c AL1600 7a47974ec8aff2c1e5383f2f6e177bb5
# 3 3cb128716ea20130263a04106234e436 AL1600 7a47974ec8aff2c1e5383f2f6e177bb5
# 4 3eff2d8a1ba50dc876eafc3d5e5579f8 AL1600 7a47974ec8aff2c1e5383f2f6e177bb5
# 5 38bb5dd7980ee82cf4692388b3d09469 AL1600 7a47974ec8aff2c1e5383f2f6e177bb5
# 6 1d303a84e2c1f6add44e721a50800f69 AL1600 7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 AL1600 0.001 0.4065 0.4065
# 2 AL1600 0.001 0.4525 0.4525
# 3 AL1600 0.001 0.4539 0.4539
# 4 AL1600 0.001 0.4718 0.4718
# 5 AL1600 0.001 0.5997 0.5997
# 6 AL1600 0.001 0.4045 0.4045

# %%
AL1600_1 = subset(AL1600, cor < 0)
length(AL1600_1$cor)/length(AL1600$cor)
1-length(AL1600_1$cor)/length(AL1600$cor)
# Out:
# [1] 0.3696172
# [1] 0.6303828

# %%
AL1600_2 = AL1600[,c(1,3)]
AL1600_net = graph_from_edgelist(as.matrix(AL1600_2), directed = FALSE)
length(V(AL1600_net))
length(E(AL1600_net))
# average degree
mean(degree(AL1600_net))
# average betweenness
mean(betweenness(AL1600_net))
# clustering coefficient
transitivity(AL1600_net)
# modularity
AL1600_m = cluster_fast_greedy(AL1600_net)
modularity(AL1600_net, membership(AL1600_m))
# Out:
# [1] 155
# [1] 836
# [1] 10.7871
# [1] 103.4774
# [1] 0.4834274
# [1] 0.2442681

# %%
AL1700 = read.table(file = "Network/Fastspar/AL1700.txt", header =T)
head(AL1700)
# Out:
#   ID2                              treat2 ID1
# 1 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1700 aac9c2855db08f8b8c6eda943aebd77c
# 2 3cb128716ea20130263a04106234e436 AL1700 aac9c2855db08f8b8c6eda943aebd77c
# 3 2932e22e69f99fd3d7abe6bb86e63850 AL1700 aac9c2855db08f8b8c6eda943aebd77c
# 4 aeffc44cf27980934d2cfa4922f7f564 AL1700 aac9c2855db08f8b8c6eda943aebd77c
# 5 4b9801fee1dbae8635b903d25f5ac16e AL1700 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 AL1700 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL1700 0.001  0.6401 0.6401
# 2 AL1700 0.001  0.6602 0.6602
# 3 AL1700 0.001  0.4419 0.4419
# 4 AL1700 0.001  0.5019 0.5019
# 5 AL1700 0.001  0.5295 0.5295
# 6 AL1700 0.001 -0.5306 0.5306

# %%
AL1700_1 = subset(AL1700, cor < 0)
length(AL1700_1$cor)/length(AL1700$cor)
1-length(AL1700_1$cor)/length(AL1700$cor)
# Out:
# [1] 0.3804348
# [1] 0.6195652

# %%
AL1700_2 = AL1700[,c(1,3)]
AL1700_net = graph_from_edgelist(as.matrix(AL1700_2), directed = FALSE)
length(V(AL1700_net))
length(E(AL1700_net))
# average degree
mean(degree(AL1700_net))
# average betweenness
mean(betweenness(AL1700_net))
# clustering coefficient
transitivity(AL1700_net)
# modularity
AL1700_m = cluster_fast_greedy(AL1700_net)
modularity(AL1700_net, membership(AL1700_m))
# Out:
# [1] 148
# [1] 828
# [1] 11.18919
# [1] 93.13514
# [1] 0.5212682
# [1] 0.2250461

# %%
AL1800 = read.table(file = "Network/Fastspar/AL1800.txt", header =T)
head(AL1800)
# Out:
#   ID2                              treat2 ID1
# 1 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1800 aac9c2855db08f8b8c6eda943aebd77c
# 2 3cb128716ea20130263a04106234e436 AL1800 aac9c2855db08f8b8c6eda943aebd77c
# 3 2932e22e69f99fd3d7abe6bb86e63850 AL1800 aac9c2855db08f8b8c6eda943aebd77c
# 4 aeffc44cf27980934d2cfa4922f7f564 AL1800 aac9c2855db08f8b8c6eda943aebd77c
# 5 fb435faf18ac9b76692687b973a617cc AL1800 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 AL1800 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL1800 0.001  0.6401 0.6401
# 2 AL1800 0.001  0.6602 0.6602
# 3 AL1800 0.001  0.4419 0.4419
# 4 AL1800 0.001  0.5019 0.5019
# 5 AL1800 0.001  0.5940 0.5940
# 6 AL1800 0.001 -0.5306 0.5306

# %%
AL1800_1 = subset(AL1800, cor < 0)
length(AL1800_1$cor)/length(AL1800$cor)
1-length(AL1800_1$cor)/length(AL1800$cor)
# Out:
# [1] 0.3374844
# [1] 0.6625156

# %%
AL1800_2 = AL1800[,c(1,3)]
AL1800_net = graph_from_edgelist(as.matrix(AL1800_2), directed = FALSE)
length(V(AL1800_net))
length(E(AL1800_net))
# average degree
mean(degree(AL1800_net))
# average betweenness
mean(betweenness(AL1800_net))
# clustering coefficient
transitivity(AL1800_net)
# modularity
AL1800_m = cluster_fast_greedy(AL1800_net)
modularity(AL1800_net, membership(AL1800_m))
# Out:
# [1] 157
# [1] 803
# [1] 10.2293
# [1] 93.19108
# [1] 0.5065967
# [1] 0.2503563

# %%
AL1900 = read.table(file = "Network/Fastspar/AL1900.txt", header =T)
head(AL1900)
# Out:
#   ID2                              treat2 ID1
# 1 65bb0fbfd950451626807f4dd07771fe AL1900 aac9c2855db08f8b8c6eda943aebd77c
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 AL1900 aac9c2855db08f8b8c6eda943aebd77c
# 3 3cb128716ea20130263a04106234e436 AL1900 aac9c2855db08f8b8c6eda943aebd77c
# 4 2932e22e69f99fd3d7abe6bb86e63850 AL1900 aac9c2855db08f8b8c6eda943aebd77c
# 5 aeffc44cf27980934d2cfa4922f7f564 AL1900 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 AL1900 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL1900 0.001  0.6059 0.6059
# 2 AL1900 0.001  0.6401 0.6401
# 3 AL1900 0.001  0.6602 0.6602
# 4 AL1900 0.001  0.4419 0.4419
# 5 AL1900 0.001  0.5019 0.5019
# 6 AL1900 0.001 -0.5306 0.5306

# %%
AL1900_1 = subset(AL1900, cor < 0)
length(AL1900_1$cor)/length(AL1900$cor)
1-length(AL1900_1$cor)/length(AL1900$cor)
# Out:
# [1] 0.3467337
# [1] 0.6532663

# %%
AL1900_2 = AL1900[,c(1,3)]
AL1900_net = graph_from_edgelist(as.matrix(AL1900_2), directed = FALSE)
length(V(AL1900_net))
length(E(AL1900_net))
# average degree
mean(degree(AL1900_net))
# average betweenness
mean(betweenness(AL1900_net))
# clustering coefficient
transitivity(AL1900_net)
# modularity
AL1900_m = cluster_fast_greedy(AL1900_net)
modularity(AL1900_net, membership(AL1900_m))
# Out:
# [1] 159
# [1] 796
# [1] 10.01258
# [1] 106.0818
# [1] 0.5004412
# [1] 0.2462209

# %%
AL2000 = read.table(file = "Network/Fastspar/AL2000.txt", header =T)
head(AL2000)
# Out:
#   ID2                              treat2 ID1
# 1 65bb0fbfd950451626807f4dd07771fe AL2000 aac9c2855db08f8b8c6eda943aebd77c
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 AL2000 aac9c2855db08f8b8c6eda943aebd77c
# 3 3cb128716ea20130263a04106234e436 AL2000 aac9c2855db08f8b8c6eda943aebd77c
# 4 2932e22e69f99fd3d7abe6bb86e63850 AL2000 aac9c2855db08f8b8c6eda943aebd77c
# 5 aeffc44cf27980934d2cfa4922f7f564 AL2000 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 AL2000 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL2000 0.001  0.6059 0.6059
# 2 AL2000 0.001  0.6401 0.6401
# 3 AL2000 0.001  0.6602 0.6602
# 4 AL2000 0.001  0.4419 0.4419
# 5 AL2000 0.001  0.5019 0.5019
# 6 AL2000 0.001 -0.5306 0.5306

# %%
AL2000_1 = subset(AL2000, cor < 0)
length(AL2000_1$cor)/length(AL2000$cor)
1-length(AL2000_1$cor)/length(AL2000$cor)
# Out:
# [1] 0.3220339
# [1] 0.6779661

# %%
AL2000_2 = AL2000[,c(1,3)]
AL2000_net = graph_from_edgelist(as.matrix(AL2000_2), directed = FALSE)
length(V(AL2000_net))
length(E(AL2000_net))
# average degree
mean(degree(AL2000_net))
# average betweenness
mean(betweenness(AL2000_net))
# clustering coefficient
transitivity(AL2000_net)
# modularity
AL2000_m = cluster_fast_greedy(AL2000_net)
modularity(AL2000_net, membership(AL2000_m))
# Out:
# [1] 156
# [1] 767
# [1] 9.833333
# [1] 120.1474
# [1] 0.4897959
# [1] 0.2559329

# %%
AL2100 = read.table(file = "Network/Fastspar/AL2100.txt", header =T)
head(AL2100)
# Out:
#   ID2                              treat2 ID1
# 1 824010500d0911bcd70f690960a8e859 AL2100 aa3c7749c78163f5be32feea6e2f1eba
# 2 c146c122dd4c16fbf2474980f772f9e1 AL2100 d424d627423e83b71ddf5ab0429aeef0
# 3 bc4f5192c98cc094f9afc8015b675778 AL2100 d424d627423e83b71ddf5ab0429aeef0
# 4 04c53787739acaf3388248ad5b8b7c76 AL2100 17a6627b3e512658dd3424fedb302bb7
# 5 3cb128716ea20130263a04106234e436 AL2100 9ec8e79f52b80a2ccc6ea2606c005ea5
# 6 4b9801fee1dbae8635b903d25f5ac16e AL2100 9ec8e79f52b80a2ccc6ea2606c005ea5
#   treat1 pval  cor     abscor
# 1 AL2100 0.001 -0.4058 0.4058
# 2 AL2100 0.001  0.4688 0.4688
# 3 AL2100 0.001  0.4404 0.4404
# 4 AL2100 0.001  0.4309 0.4309
# 5 AL2100 0.001  0.7009 0.7009
# 6 AL2100 0.001  0.5102 0.5102

# %%
AL2100_1 = subset(AL2100, cor < 0)
length(AL2100_1$cor)/length(AL2100$cor)
1-length(AL2100_1$cor)/length(AL2100$cor)
# Out:
# [1] 0.22
# [1] 0.78

# %%
AL2100_2 = AL2100[,c(1,3)]
AL2100_net = graph_from_edgelist(as.matrix(AL2100_2), directed = FALSE)
length(V(AL2100_net))
length(E(AL2100_net))
# average degree
mean(degree(AL2100_net))
# average betweenness
mean(betweenness(AL2100_net))
# clustering coefficient
transitivity(AL2100_net)
# modularity
AL2100_m = cluster_fast_greedy(AL2100_net)
modularity(AL2100_net, membership(AL2100_m))
# Out:
# [1] 137
# [1] 600
# [1] 8.759124
# [1] 103.7007
# [1] 0.468259
# [1] 0.2907514

# %%
AL2200 = read.table(file = "Network/Fastspar/AL2200.txt", header =T)
head(AL2200)
# Out:
#   ID2                              treat2 ID1
# 1 65bb0fbfd950451626807f4dd07771fe AL2200 aac9c2855db08f8b8c6eda943aebd77c
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 AL2200 aac9c2855db08f8b8c6eda943aebd77c
# 3 2932e22e69f99fd3d7abe6bb86e63850 AL2200 aac9c2855db08f8b8c6eda943aebd77c
# 4 aeffc44cf27980934d2cfa4922f7f564 AL2200 aac9c2855db08f8b8c6eda943aebd77c
# 5 4b9801fee1dbae8635b903d25f5ac16e AL2200 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 AL2200 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL2200 0.001  0.6059 0.6059
# 2 AL2200 0.001  0.6401 0.6401
# 3 AL2200 0.001  0.4419 0.4419
# 4 AL2200 0.001  0.5019 0.5019
# 5 AL2200 0.001  0.5295 0.5295
# 6 AL2200 0.001 -0.5306 0.5306

# %%
AL2200_1 = subset(AL2200, cor < 0)
length(AL2200_1$cor)/length(AL2200$cor)
1-length(AL2200_1$cor)/length(AL2200$cor)
# Out:
# [1] 0.3514451
# [1] 0.6485549

# %%
AL2200_2 = AL2200[,c(1,3)]
AL2200_net = graph_from_edgelist(as.matrix(AL2200_2), directed = FALSE)
length(V(AL2200_net))
length(E(AL2200_net))
# average degree
mean(degree(AL2200_net))
# average betweenness
mean(betweenness(AL2200_net))
# clustering coefficient
transitivity(AL2200_net)
# modularity
AL2200_m = cluster_fast_greedy(AL2200_net)
modularity(AL2200_net, membership(AL2200_m))
# Out:
# [1] 161
# [1] 865
# [1] 10.74534
# [1] 109.4348
# [1] 0.4956746
# [1] 0.2585753

# %%
AL2300 = read.table(file = "Network/Fastspar/AL2300.txt", header =T)
head(AL2300)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL2300 79697d6bda362d5e6b2a79a4a1d91034
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 AL2300 79697d6bda362d5e6b2a79a4a1d91034
# 3 65bb0fbfd950451626807f4dd07771fe AL2300 aac9c2855db08f8b8c6eda943aebd77c
# 4 9ec8e79f52b80a2ccc6ea2606c005ea5 AL2300 aac9c2855db08f8b8c6eda943aebd77c
# 5 2932e22e69f99fd3d7abe6bb86e63850 AL2300 aac9c2855db08f8b8c6eda943aebd77c
# 6 aeffc44cf27980934d2cfa4922f7f564 AL2300 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 AL2300 0.001 0.4292 0.4292
# 2 AL2300 0.001 0.4132 0.4132
# 3 AL2300 0.001 0.6059 0.6059
# 4 AL2300 0.001 0.6401 0.6401
# 5 AL2300 0.001 0.4419 0.4419
# 6 AL2300 0.001 0.5019 0.5019

# %%
AL2300_1 = subset(AL2300, cor < 0)
length(AL2300_1$cor)/length(AL2300$cor)
1-length(AL2300_1$cor)/length(AL2300$cor)
# Out:
# [1] 0.2684366
# [1] 0.7315634

# %%
AL2300_2 = AL2300[,c(1,3)]
AL2300_net = graph_from_edgelist(as.matrix(AL2300_2), directed = FALSE)
length(V(AL2300_net))
length(E(AL2300_net))
# average degree
mean(degree(AL2300_net))
# average betweenness
mean(betweenness(AL2300_net))
# clustering coefficient
transitivity(AL2300_net)
# modularity
AL2300_m = cluster_fast_greedy(AL2300_net)
modularity(AL2300_net, membership(AL2300_m))
# Out:
# [1] 141
# [1] 678
# [1] 9.617021
# [1] 107.9291
# [1] 0.4683003
# [1] 0.2668083

# %%
AL2400 = read.table(file = "Network/Fastspar/AL2400.txt", header =T)
head(AL2400)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c AL2400 7a47974ec8aff2c1e5383f2f6e177bb5
# 2 7e6dbf367068c046b28806cc543ea1e1 AL2400 7a47974ec8aff2c1e5383f2f6e177bb5
# 3 22df7ae850b69bc22e975cf243ef9a9a AL2400 7a47974ec8aff2c1e5383f2f6e177bb5
# 4 8ee44c2135047317811efa7f11a379ce AL2400 7a47974ec8aff2c1e5383f2f6e177bb5
# 5 0de0223eaab45574b0d96447cc7bdd22 AL2400 7a47974ec8aff2c1e5383f2f6e177bb5
# 6 9ec8e79f52b80a2ccc6ea2606c005ea5 AL2400 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 AL2400 0.001  0.4525 0.4525
# 2 AL2400 0.001  0.4818 0.4818
# 3 AL2400 0.001 -0.4249 0.4249
# 4 AL2400 0.001 -0.4217 0.4217
# 5 AL2400 0.001 -0.4278 0.4278
# 6 AL2400 0.001  0.6401 0.6401

# %%
AL2400_1 = subset(AL2400, cor < 0)
length(AL2400_1$cor)/length(AL2400$cor)
1-length(AL2400_1$cor)/length(AL2400$cor)
# Out:
# [1] 0.2534776
# [1] 0.7465224

# %%
AL2400_2 = AL2400[,c(1,3)]
AL2400_net = graph_from_edgelist(as.matrix(AL2400_2), directed = FALSE)
length(V(AL2400_net))
length(E(AL2400_net))
# average degree
mean(degree(AL2400_net))
# average betweenness
mean(betweenness(AL2400_net))
# clustering coefficient
transitivity(AL2400_net)
# modularity
AL2400_m = cluster_fast_greedy(AL2400_net)
modularity(AL2400_net, membership(AL2400_m))
# Out:
# [1] 133
# [1] 647
# [1] 9.729323
# [1] 105.4737
# [1] 0.4625761
# [1] 0.2700599

# %%
EA600 = read.table(file = "Network/Fastspar/EA600.txt", header =T)
head(EA600)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA600  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c EA600  7a47974ec8aff2c1e5383f2f6e177bb5
# 3 3cb128716ea20130263a04106234e436 EA600  7a47974ec8aff2c1e5383f2f6e177bb5
# 4 7e6dbf367068c046b28806cc543ea1e1 EA600  7a47974ec8aff2c1e5383f2f6e177bb5
# 5 3eff2d8a1ba50dc876eafc3d5e5579f8 EA600  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 38bb5dd7980ee82cf4692388b3d09469 EA600  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 EA600  0.001 0.4065 0.4065
# 2 EA600  0.001 0.4525 0.4525
# 3 EA600  0.001 0.4539 0.4539
# 4 EA600  0.001 0.4818 0.4818
# 5 EA600  0.001 0.4718 0.4718
# 6 EA600  0.001 0.5997 0.5997

# %%
EA600_1 = subset(EA600, cor < 0)
length(EA600_1$cor)/length(EA600$cor)
1-length(EA600_1$cor)/length(EA600$cor)
# Out:
# [1] 0.3211382
# [1] 0.6788618

# %%
EA600_2 = EA600[,c(1,3)]
EA600_net = graph_from_edgelist(as.matrix(EA600_2), directed = FALSE)
length(V(EA600_net))
length(E(EA600_net))
# average degree
mean(degree(EA600_net))
# average betweenness
mean(betweenness(EA600_net))
# clustering coefficient
transitivity(EA600_net)
# modularity
EA600_m = cluster_fast_greedy(EA600_net)
modularity(EA600_net, membership(EA600_m))
# Out:
# [1] 148
# [1] 984
# [1] 13.2973
# [1] 90.92568
# [1] 0.474845
# [1] 0.2194518

# %%
EA700 = read.table(file = "Network/Fastspar/EA700.txt", header =T)
head(EA700)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA700  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 EA700  3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 EA700  3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 EA700  3d2258d3cda1b5305d5d1acc7b4df677
# 5 38f440bd83eb3f9e3064522f3d0db449 EA700  3d2258d3cda1b5305d5d1acc7b4df677
# 6 aac9c2855db08f8b8c6eda943aebd77c EA700  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor     abscor
# 1 EA700  0.001  0.4065 0.4065
# 2 EA700  0.001  0.4235 0.4235
# 3 EA700  0.001 -0.4704 0.4704
# 4 EA700  0.001  0.4074 0.4074
# 5 EA700  0.001  0.4028 0.4028
# 6 EA700  0.001  0.4525 0.4525

# %%
EA700_1 = subset(EA700, cor < 0)
length(EA700_1$cor)/length(EA700$cor)
1-length(EA700_1$cor)/length(EA700$cor)
# Out:
# [1] 0.256351
# [1] 0.743649

# %%
EA700_2 = EA700[,c(1,3)]
EA700_net = graph_from_edgelist(as.matrix(EA700_2), directed = FALSE)
length(V(EA700_net))
length(E(EA700_net))
# average degree
mean(degree(EA700_net))
# average betweenness
mean(betweenness(EA700_net))
# clustering coefficient
transitivity(EA700_net)
# modularity
EA700_m = cluster_fast_greedy(EA700_net)
modularity(EA700_net, membership(EA700_m))
# Out:
# [1] 134
# [1] 866
# [1] 12.92537
# [1] 77.38806
# [1] 0.4678814
# [1] 0.2078989

# %%
EA800 = read.table(file = "Network/Fastspar/EA800.txt", header =T)
head(EA800)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA800  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 EA800  3d2258d3cda1b5305d5d1acc7b4df677
# 3 c1ed637b068ec1ae35761ae587061e72 EA800  3d2258d3cda1b5305d5d1acc7b4df677
# 4 38f440bd83eb3f9e3064522f3d0db449 EA800  3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c EA800  7a47974ec8aff2c1e5383f2f6e177bb5
# 6 3cb128716ea20130263a04106234e436 EA800  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 EA800  0.001 0.4065 0.4065
# 2 EA800  0.001 0.4235 0.4235
# 3 EA800  0.001 0.4074 0.4074
# 4 EA800  0.001 0.4028 0.4028
# 5 EA800  0.001 0.4525 0.4525
# 6 EA800  0.001 0.4539 0.4539

# %%
EA800_1 = subset(EA800, cor < 0)
length(EA800_1$cor)/length(EA800$cor)
1-length(EA800_1$cor)/length(EA800$cor)
# Out:
# [1] 0.1291727
# [1] 0.8708273

# %%
EA800_2 = EA800[,c(1,3)]
EA800_net = graph_from_edgelist(as.matrix(EA800_2), directed = FALSE)
length(V(EA800_net))
length(E(EA800_net))
# average degree
mean(degree(EA800_net))
# average betweenness
mean(betweenness(EA800_net))
# clustering coefficient
transitivity(EA800_net)
# modularity
EA800_m = cluster_fast_greedy(EA800_net)
modularity(EA800_net, membership(EA800_m))
# Out:
# [1] 118
# [1] 689
# [1] 11.67797
# [1] 68.82203
# [1] 0.4616745
# [1] 0.2161891

# %%
EA900 = read.table(file = "Network/Fastspar/EA900.txt", header =T)
head(EA900)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA900  6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 EA900  3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 EA900  3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 EA900  3d2258d3cda1b5305d5d1acc7b4df677
# 5 38f440bd83eb3f9e3064522f3d0db449 EA900  3d2258d3cda1b5305d5d1acc7b4df677
# 6 aac9c2855db08f8b8c6eda943aebd77c EA900  7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor     abscor
# 1 EA900  0.001  0.4065 0.4065
# 2 EA900  0.001  0.4235 0.4235
# 3 EA900  0.001 -0.4704 0.4704
# 4 EA900  0.001  0.4074 0.4074
# 5 EA900  0.001  0.4028 0.4028
# 6 EA900  0.001  0.4525 0.4525

# %%
EA900_1 = subset(EA900, cor < 0)
length(EA900_1$cor)/length(EA900$cor)
1-length(EA900_1$cor)/length(EA900$cor)
# Out:
# [1] 0.3134615
# [1] 0.6865385

# %%
EA900_2 = EA900[,c(1,3)]
EA900_net = graph_from_edgelist(as.matrix(EA900_2), directed = FALSE)
length(V(EA900_net))
length(E(EA900_net))
# average degree
mean(degree(EA900_net))
# average betweenness
mean(betweenness(EA900_net))
# clustering coefficient
transitivity(EA900_net)
# modularity
EA900_m = cluster_fast_greedy(EA900_net)
modularity(EA900_net, membership(EA900_m))
# Out:
# [1] 155
# [1] 1040
# [1] 13.41935
# [1] 94.76129
# [1] 0.4623251
# [1] 0.2090953

# %%
EA1000 = read.table(file = "Network/Fastspar/EA1000.txt", header =T)
head(EA1000)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
# 2 3cb128716ea20130263a04106234e436 EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
# 3 7e6dbf367068c046b28806cc543ea1e1 EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
# 4 3eff2d8a1ba50dc876eafc3d5e5579f8 EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
# 5 38bb5dd7980ee82cf4692388b3d09469 EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
# 6 1d303a84e2c1f6add44e721a50800f69 EA1000 7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor    abscor
# 1 EA1000 0.001 0.4525 0.4525
# 2 EA1000 0.001 0.4539 0.4539
# 3 EA1000 0.001 0.4818 0.4818
# 4 EA1000 0.001 0.4718 0.4718
# 5 EA1000 0.001 0.5997 0.5997
# 6 EA1000 0.001 0.4045 0.4045

# %%
EA1000_1 = subset(EA1000, cor < 0)
length(EA1000_1$cor)/length(EA1000$cor)
1-length(EA1000_1$cor)/length(EA1000$cor)
# Out:
# [1] 0.3196078
# [1] 0.6803922

# %%
EA1000_2 = EA1000[,c(1,3)]
EA1000_net = graph_from_edgelist(as.matrix(EA1000_2), directed = FALSE)
length(V(EA1000_net))
length(E(EA1000_net))
# average degree
mean(degree(EA1000_net))
# average betweenness
mean(betweenness(EA1000_net))
# clustering coefficient
transitivity(EA1000_net)
# modularity
EA1000_m = cluster_fast_greedy(EA1000_net)
modularity(EA1000_net, membership(EA1000_m))
# Out:
# [1] 153
# [1] 1020
# [1] 13.33333
# [1] 101.2614
# [1] 0.4651736
# [1] 0.1927595

# %%
EA1100 = read.table(file = "Network/Fastspar/EA1100.txt", header =T)
head(EA1100)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1100 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 EA1100 3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 EA1100 3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 EA1100 3d2258d3cda1b5305d5d1acc7b4df677
# 5 38f440bd83eb3f9e3064522f3d0db449 EA1100 3d2258d3cda1b5305d5d1acc7b4df677
# 6 aac9c2855db08f8b8c6eda943aebd77c EA1100 7a47974ec8aff2c1e5383f2f6e177bb5
#   treat1 pval  cor     abscor
# 1 EA1100 0.001  0.4065 0.4065
# 2 EA1100 0.001  0.4235 0.4235
# 3 EA1100 0.001 -0.4704 0.4704
# 4 EA1100 0.001  0.4074 0.4074
# 5 EA1100 0.001  0.4028 0.4028
# 6 EA1100 0.001  0.4525 0.4525

# %%
EA1100_1 = subset(EA1100, cor < 0)
length(EA1100_1$cor)/length(EA1100$cor)
1-length(EA1100_1$cor)/length(EA1100$cor)
# Out:
# [1] 0.3846774
# [1] 0.6153226

# %%
EA1100_2 = EA1100[,c(1,3)]
EA1100_net = graph_from_edgelist(as.matrix(EA1100_2), directed = FALSE)
length(V(EA1100_net))
length(E(EA1100_net))
# average degree
mean(degree(EA1100_net))
# average betweenness
mean(betweenness(EA1100_net))
# clustering coefficient
transitivity(EA1100_net)
# modularity
EA1100_m = cluster_fast_greedy(EA1100_net)
modularity(EA1100_net, membership(EA1100_m))
# Out:
# [1] 161
# [1] 1240
# [1] 15.40373
# [1] 88.29193
# [1] 0.4952897
# [1] 0.2043291

# %%
EA1200 = read.table(file = "Network/Fastspar/EA1200.txt", header =T)
head(EA1200)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1200 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c EA1200 79697d6bda362d5e6b2a79a4a1d91034
# 3 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1200 79697d6bda362d5e6b2a79a4a1d91034
# 4 4b9801fee1dbae8635b903d25f5ac16e EA1200 79697d6bda362d5e6b2a79a4a1d91034
# 5 7f098bf95212dc6a706bbad6ad44a306 EA1200 79697d6bda362d5e6b2a79a4a1d91034
# 6 65bb0fbfd950451626807f4dd07771fe EA1200 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 EA1200 0.001 0.4065 0.4065
# 2 EA1200 0.001 0.4292 0.4292
# 3 EA1200 0.001 0.4132 0.4132
# 4 EA1200 0.001 0.4519 0.4519
# 5 EA1200 0.001 0.4495 0.4495
# 6 EA1200 0.001 0.6059 0.6059

# %%
EA1200_1 = subset(EA1200, cor < 0)
length(EA1200_1$cor)/length(EA1200$cor)
1-length(EA1200_1$cor)/length(EA1200$cor)
# Out:
# [1] 0.4144869
# [1] 0.5855131

# %%
EA1200_2 = EA1200[,c(1,3)]
EA1200_net = graph_from_edgelist(as.matrix(EA1200_2), directed = FALSE)
length(V(EA1200_net))
length(E(EA1200_net))
# average degree
mean(degree(EA1200_net))
# average betweenness
mean(betweenness(EA1200_net))
# clustering coefficient
transitivity(EA1200_net)
# modularity
EA1200_m = cluster_fast_greedy(EA1200_net)
modularity(EA1200_net, membership(EA1200_m))
# Out:
# [1] 159
# [1] 994
# [1] 12.50314
# [1] 93.86792
# [1] 0.525
# [1] 0.1973951

# %%
EA1300 = read.table(file = "Network/Fastspar/EA1300.txt", header =T)
head(EA1300)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1300 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 aac9c2855db08f8b8c6eda943aebd77c EA1300 79697d6bda362d5e6b2a79a4a1d91034
# 3 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1300 79697d6bda362d5e6b2a79a4a1d91034
# 4 4b9801fee1dbae8635b903d25f5ac16e EA1300 79697d6bda362d5e6b2a79a4a1d91034
# 5 7f098bf95212dc6a706bbad6ad44a306 EA1300 79697d6bda362d5e6b2a79a4a1d91034
# 6 65bb0fbfd950451626807f4dd07771fe EA1300 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 EA1300 0.001 0.4065 0.4065
# 2 EA1300 0.001 0.4292 0.4292
# 3 EA1300 0.001 0.4132 0.4132
# 4 EA1300 0.001 0.4519 0.4519
# 5 EA1300 0.001 0.4495 0.4495
# 6 EA1300 0.001 0.6059 0.6059

# %%
EA1300_1 = subset(EA1300, cor < 0)
length(EA1300_1$cor)/length(EA1300$cor)
1-length(EA1300_1$cor)/length(EA1300$cor)
# Out:
# [1] 0.4221636
# [1] 0.5778364

# %%
EA1300_2 = EA1300[,c(1,3)]
EA1300_net = graph_from_edgelist(as.matrix(EA1300_2), directed = FALSE)
length(V(EA1300_net))
length(E(EA1300_net))
# average degree
mean(degree(EA1300_net))
# average betweenness
mean(betweenness(EA1300_net))
# clustering coefficient
transitivity(EA1300_net)
# modularity
EA1300_m = cluster_fast_greedy(EA1300_net)
modularity(EA1300_net, membership(EA1300_m))
# Out:
# [1] 165
# [1] 1137
# [1] 13.78182
# [1] 95
# [1] 0.5267599
# [1] 0.1779266

# %%
EA1400 = read.table(file = "Network/Fastspar/EA1400.txt", header =T)
head(EA1400)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1400 6b9d995dfc0b8c790f9bc6add0cd1c11
# 2 3f06c7bc691bbb0332b9ceac51b62666 EA1400 3d2258d3cda1b5305d5d1acc7b4df677
# 3 844e647bddb234e7ebef6630b017b072 EA1400 3d2258d3cda1b5305d5d1acc7b4df677
# 4 c1ed637b068ec1ae35761ae587061e72 EA1400 3d2258d3cda1b5305d5d1acc7b4df677
# 5 aac9c2855db08f8b8c6eda943aebd77c EA1400 79697d6bda362d5e6b2a79a4a1d91034
# 6 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1400 79697d6bda362d5e6b2a79a4a1d91034
#   treat1 pval  cor     abscor
# 1 EA1400 0.001  0.4065 0.4065
# 2 EA1400 0.001  0.4235 0.4235
# 3 EA1400 0.001 -0.4704 0.4704
# 4 EA1400 0.001  0.4074 0.4074
# 5 EA1400 0.001  0.4292 0.4292
# 6 EA1400 0.001  0.4132 0.4132

# %%
EA1400_1 = subset(EA1400, cor < 0)
length(EA1400_1$cor)/length(EA1400$cor)
1-length(EA1400_1$cor)/length(EA1400$cor)
# Out:
# [1] 0.4244131
# [1] 0.5755869

# %%
EA1400_2 = EA1400[,c(1,3)]
EA1400_net = graph_from_edgelist(as.matrix(EA1400_2), directed = FALSE)
length(V(EA1400_net))
length(E(EA1400_net))
# average degree
mean(degree(EA1400_net))
# average betweenness
mean(betweenness(EA1400_net))
# clustering coefficient
transitivity(EA1400_net)
# modularity
EA1400_m = cluster_fast_greedy(EA1400_net)
modularity(EA1400_net, membership(EA1400_m))
# Out:
# [1] 158
# [1] 1065
# [1] 13.48101
# [1] 90.56962
# [1] 0.5372568
# [1] 0.1746761

# %%
EA1500 = read.table(file = "Network/Fastspar/EA1500.txt", header = T)
head(EA1500)
# Out:
#   ID2                              treat2 ID1
# 1 65bb0fbfd950451626807f4dd07771fe EA1500 aac9c2855db08f8b8c6eda943aebd77c
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1500 aac9c2855db08f8b8c6eda943aebd77c
# 3 3cb128716ea20130263a04106234e436 EA1500 aac9c2855db08f8b8c6eda943aebd77c
# 4 2932e22e69f99fd3d7abe6bb86e63850 EA1500 aac9c2855db08f8b8c6eda943aebd77c
# 5 aeffc44cf27980934d2cfa4922f7f564 EA1500 aac9c2855db08f8b8c6eda943aebd77c
# 6 4b9801fee1dbae8635b903d25f5ac16e EA1500 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 EA1500 0.001 0.6059 0.6059
# 2 EA1500 0.001 0.6401 0.6401
# 3 EA1500 0.001 0.6602 0.6602
# 4 EA1500 0.001 0.4419 0.4419
# 5 EA1500 0.001 0.5019 0.5019
# 6 EA1500 0.001 0.5295 0.5295

# %%
EA1500_1 = subset(EA1500, cor < 0)
length(EA1500_1$cor)/length(EA1500$cor)
1-length(EA1500_1$cor)/length(EA1500$cor)
# Out:
# [1] 0.4209446
# [1] 0.5790554

# %%
EA1500_2 = EA1500[,c(1,3)]
EA1500_net = graph_from_edgelist(as.matrix(EA1500_2), directed = FALSE)
length(V(EA1500_net))
length(E(EA1500_net))
# average degree
mean(degree(EA1500_net))
# average betweenness
mean(betweenness(EA1500_net))
# clustering coefficient
transitivity(EA1500_net)
# modularity
EA1500_m = cluster_fast_greedy(EA1500_net)
modularity(EA1500_net, membership(EA1500_m))
# Out:
# [1] 158
# [1] 974
# [1] 12.32911
# [1] 99.94937
# [1] 0.5528777
# [1] 0.189024

# %%
EA1600 = read.table(file = "Network/Fastspar/EA1600.txt", header =T)
head(EA1600)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1600 79697d6bda362d5e6b2a79a4a1d91034
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1600 79697d6bda362d5e6b2a79a4a1d91034
# 3 4b9801fee1dbae8635b903d25f5ac16e EA1600 79697d6bda362d5e6b2a79a4a1d91034
# 4 7f098bf95212dc6a706bbad6ad44a306 EA1600 79697d6bda362d5e6b2a79a4a1d91034
# 5 65bb0fbfd950451626807f4dd07771fe EA1600 aac9c2855db08f8b8c6eda943aebd77c
# 6 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1600 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 EA1600 0.001 0.4292 0.4292
# 2 EA1600 0.001 0.4132 0.4132
# 3 EA1600 0.001 0.4519 0.4519
# 4 EA1600 0.001 0.4495 0.4495
# 5 EA1600 0.001 0.6059 0.6059
# 6 EA1600 0.001 0.6401 0.6401

# %%
EA1600_1 = subset(EA1600, cor < 0)
length(EA1600_1$cor)/length(EA1600$cor)
1-length(EA1600_1$cor)/length(EA1600$cor)
# Out:
# [1] 0.4183168
# [1] 0.5816832

# %%
EA1600_2 = EA1600[,c(1,3)]
EA1600_net = graph_from_edgelist(as.matrix(EA1600_2), directed = FALSE)
length(V(EA1600_net))
length(E(EA1600_net))
# average degree
mean(degree(EA1600_net))
# average betweenness
mean(betweenness(EA1600_net))
# clustering coefficient
transitivity(EA1600_net)
# modularity
EA1600_m = cluster_fast_greedy(EA1600_net)
modularity(EA1600_net, membership(EA1600_m))
# Out:
# [1] 174
# [1] 1212
# [1] 13.93103
# [1] 112.8966
# [1] 0.555216
# [1] 0.1930594

# %%
EA1700 = read.table(file = "Network/Fastspar/EA1700.txt", header =T)
head(EA1700)
# Out:
#   ID2                              treat2 ID1
# 1 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1700 79697d6bda362d5e6b2a79a4a1d91034
# 2 4b9801fee1dbae8635b903d25f5ac16e EA1700 79697d6bda362d5e6b2a79a4a1d91034
# 3 824010500d0911bcd70f690960a8e859 EA1700 aa3c7749c78163f5be32feea6e2f1eba
# 4 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1700 65bb0fbfd950451626807f4dd07771fe
# 5 3cb128716ea20130263a04106234e436 EA1700 65bb0fbfd950451626807f4dd07771fe
# 6 aeffc44cf27980934d2cfa4922f7f564 EA1700 65bb0fbfd950451626807f4dd07771fe
#   treat1 pval  cor     abscor
# 1 EA1700 0.001  0.4132 0.4132
# 2 EA1700 0.001  0.4519 0.4519
# 3 EA1700 0.001 -0.4058 0.4058
# 4 EA1700 0.001  0.4285 0.4285
# 5 EA1700 0.001  0.4801 0.4801
# 6 EA1700 0.001  0.4884 0.4884

# %%
EA1700_1 = subset(EA1700, cor < 0)
length(EA1700_1$cor)/length(EA1700$cor)
1-length(EA1700_1$cor)/length(EA1700$cor)
# Out:
# [1] 0.3850932
# [1] 0.6149068

# %%
EA1700_2 = EA1700[,c(1,3)]
EA1700_net = graph_from_edgelist(as.matrix(EA1700_2), directed = FALSE)
length(V(EA1700_net))
length(E(EA1700_net))
# average degree
mean(degree(EA1700_net))
# average betweenness
mean(betweenness(EA1700_net))
# clustering coefficient
transitivity(EA1700_net)
# modularity
EA1700_m = cluster_fast_greedy(EA1700_net)
modularity(EA1700_net, membership(EA1700_m))
# Out:
# [1] 147
# [1] 805
# [1] 10.95238
# [1] 101.4626
# [1] 0.5098103
# [1] 0.2259126

# %%
EA1800 = read.table(file = "Network/Fastspar/EA1800.txt", header =T)
head(EA1800)
# Out:
#   ID2                              treat2 ID1
# 1 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1800 aac9c2855db08f8b8c6eda943aebd77c
# 2 3cb128716ea20130263a04106234e436 EA1800 aac9c2855db08f8b8c6eda943aebd77c
# 3 2932e22e69f99fd3d7abe6bb86e63850 EA1800 aac9c2855db08f8b8c6eda943aebd77c
# 4 7e6dbf367068c046b28806cc543ea1e1 EA1800 aac9c2855db08f8b8c6eda943aebd77c
# 5 aeffc44cf27980934d2cfa4922f7f564 EA1800 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 EA1800 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 EA1800 0.001  0.6401 0.6401
# 2 EA1800 0.001  0.6602 0.6602
# 3 EA1800 0.001  0.4419 0.4419
# 4 EA1800 0.001  0.5277 0.5277
# 5 EA1800 0.001  0.5019 0.5019
# 6 EA1800 0.001 -0.5306 0.5306

# %%
EA1800_1 = subset(EA1800, cor < 0)
length(EA1800_1$cor)/length(EA1800$cor)
1-length(EA1800_1$cor)/length(EA1800$cor)
# Out:
# [1] 0.3545568
# [1] 0.6454432

# %%
EA1800_2 = EA1800[,c(1,3)]
EA1800_net = graph_from_edgelist(as.matrix(EA1800_2), directed = FALSE)
length(V(EA1800_net))
length(E(EA1800_net))
# average degree
mean(degree(EA1800_net))
# average betweenness
mean(betweenness(EA1800_net))
# clustering coefficient
transitivity(EA1800_net)
# modularity
EA1800_m = cluster_fast_greedy(EA1800_net)
modularity(EA1800_net, membership(EA1800_m))
# Out:
# [1] 156
# [1] 801
# [1] 10.26923
# [1] 106.141
# [1] 0.4829559
# [1] 0.2577272

# %%
EA1900 = read.table(file = "Network/Fastspar/EA1900.txt", header =T)
head(EA1900)
# Out:
#   ID2                              treat2 ID1
# 1 aac9c2855db08f8b8c6eda943aebd77c EA1900 79697d6bda362d5e6b2a79a4a1d91034
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1900 79697d6bda362d5e6b2a79a4a1d91034
# 3 7f098bf95212dc6a706bbad6ad44a306 EA1900 79697d6bda362d5e6b2a79a4a1d91034
# 4 65bb0fbfd950451626807f4dd07771fe EA1900 aac9c2855db08f8b8c6eda943aebd77c
# 5 9ec8e79f52b80a2ccc6ea2606c005ea5 EA1900 aac9c2855db08f8b8c6eda943aebd77c
# 6 3cb128716ea20130263a04106234e436 EA1900 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor    abscor
# 1 EA1900 0.001 0.4292 0.4292
# 2 EA1900 0.001 0.4132 0.4132
# 3 EA1900 0.001 0.4495 0.4495
# 4 EA1900 0.001 0.6059 0.6059
# 5 EA1900 0.001 0.6401 0.6401
# 6 EA1900 0.001 0.6602 0.6602

# %%
EA1900_1 = subset(EA1900, cor < 0)
length(EA1900_1$cor)/length(EA1900$cor)
1-length(EA1900_1$cor)/length(EA1900$cor)
# Out:
# [1] 0.3695882
# [1] 0.6304118

# %%
EA1900_2 = EA1900[,c(1,3)]
EA1900_net = graph_from_edgelist(as.matrix(EA1900_2), directed = FALSE)
length(V(EA1900_net))
length(E(EA1900_net))
# average degree
mean(degree(EA1900_net))
# average betweenness
mean(betweenness(EA1900_net))
# clustering coefficient
transitivity(EA1900_net)
# modularity
EA1900_m = cluster_fast_greedy(EA1900_net)
modularity(EA1900_net, membership(EA1900_m))
# Out:
# [1] 169
# [1] 947
# [1] 11.2071
# [1] 118.3018
# [1] 0.5129923
# [1] 0.2409766

# %%
EA2000 = read.table(file = "Network/Fastspar/EA2000.txt", header =T)
head(EA2000)
# Out:
#   ID2                              treat2 ID1
# 1 65bb0fbfd950451626807f4dd07771fe EA2000 aac9c2855db08f8b8c6eda943aebd77c
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA2000 aac9c2855db08f8b8c6eda943aebd77c
# 3 3cb128716ea20130263a04106234e436 EA2000 aac9c2855db08f8b8c6eda943aebd77c
# 4 2932e22e69f99fd3d7abe6bb86e63850 EA2000 aac9c2855db08f8b8c6eda943aebd77c
# 5 aeffc44cf27980934d2cfa4922f7f564 EA2000 aac9c2855db08f8b8c6eda943aebd77c
# 6 e3a8c711006750f5a91f7aba36569eb8 EA2000 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 EA2000 0.001  0.6059 0.6059
# 2 EA2000 0.001  0.6401 0.6401
# 3 EA2000 0.001  0.6602 0.6602
# 4 EA2000 0.001  0.4419 0.4419
# 5 EA2000 0.001  0.5019 0.5019
# 6 EA2000 0.001 -0.5306 0.5306

# %%
EA2000_1 = subset(EA2000, cor < 0)
length(EA2000_1$cor)/length(EA2000$cor)
1-length(EA2000_1$cor)/length(EA2000$cor)
# Out:
# [1] 0.3365501
# [1] 0.6634499

# %%
EA2000_2 = EA2000[,c(1,3)]
EA2000_net = graph_from_edgelist(as.matrix(EA2000_2), directed = FALSE)
length(V(EA2000_net))
length(E(EA2000_net))
# average degree
mean(degree(EA2000_net))
# average betweenness
mean(betweenness(EA2000_net))
# clustering coefficient
transitivity(EA2000_net)
# modularity
EA2000_m = cluster_fast_greedy(EA2000_net)
modularity(EA2000_net, membership(EA2000_m))
# Out:
# [1] 163
# [1] 829
# [1] 10.17178
# [1] 124
# [1] 0.4886676
# [1] 0.259417

# %%
EA2100 = read.table(file = "Network/Fastspar/EA2100.txt", header =T)
head(EA2100)
# Out:
#   ID2                              treat2 ID1
# 1 9ec8e79f52b80a2ccc6ea2606c005ea5 EA2100 aac9c2855db08f8b8c6eda943aebd77c
# 2 3cb128716ea20130263a04106234e436 EA2100 aac9c2855db08f8b8c6eda943aebd77c
# 3 2932e22e69f99fd3d7abe6bb86e63850 EA2100 aac9c2855db08f8b8c6eda943aebd77c
# 4 aeffc44cf27980934d2cfa4922f7f564 EA2100 aac9c2855db08f8b8c6eda943aebd77c
# 5 e3a8c711006750f5a91f7aba36569eb8 EA2100 aac9c2855db08f8b8c6eda943aebd77c
# 6 bc4f5192c98cc094f9afc8015b675778 EA2100 aac9c2855db08f8b8c6eda943aebd77c
#   treat1 pval  cor     abscor
# 1 EA2100 0.001  0.6401 0.6401
# 2 EA2100 0.001  0.6602 0.6602
# 3 EA2100 0.001  0.4419 0.4419
# 4 EA2100 0.001  0.5019 0.5019
# 5 EA2100 0.001 -0.5306 0.5306
# 6 EA2100 0.001  0.4092 0.4092

# %%
EA2100_1 = subset(EA2100, cor < 0)
length(EA2100_1$cor)/length(EA2100$cor)
1-length(EA2100_1$cor)/length(EA2100$cor)
# Out:
# [1] 0.3418043
# [1] 0.6581957

# %%
EA2100_2 = EA2100[,c(1,3)]
EA2100_net = graph_from_edgelist(as.matrix(EA2100_2), directed = FALSE)
length(V(EA2100_net))
length(E(EA2100_net))
# average degree
mean(degree(EA2100_net))
# average betweenness
mean(betweenness(EA2100_net))
# clustering coefficient
transitivity(EA2100_net)
# modularity
EA2100_m = cluster_fast_greedy(EA2100_net)
modularity(EA2100_net, membership(EA2100_m))
# Out:
# [1] 148
# [1] 787
# [1] 10.63514
# [1] 107.8041
# [1] 0.5061006
# [1] 0.2470748

# %%
EA2200 = read.table(file = "Network/Fastspar/EA2200.txt", header =T)
head(EA2200)
# Out:
#   ID2                              treat2 ID1
# 1 824010500d0911bcd70f690960a8e859 EA2200 aa3c7749c78163f5be32feea6e2f1eba
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA2200 65bb0fbfd950451626807f4dd07771fe
# 3 3cb128716ea20130263a04106234e436 EA2200 65bb0fbfd950451626807f4dd07771fe
# 4 7e6dbf367068c046b28806cc543ea1e1 EA2200 65bb0fbfd950451626807f4dd07771fe
# 5 aeffc44cf27980934d2cfa4922f7f564 EA2200 65bb0fbfd950451626807f4dd07771fe
# 6 7f098bf95212dc6a706bbad6ad44a306 EA2200 65bb0fbfd950451626807f4dd07771fe
#   treat1 pval  cor     abscor
# 1 EA2200 0.001 -0.4058 0.4058
# 2 EA2200 0.001  0.4285 0.4285
# 3 EA2200 0.001  0.4801 0.4801
# 4 EA2200 0.001  0.4150 0.4150
# 5 EA2200 0.001  0.4884 0.4884
# 6 EA2200 0.001  0.5373 0.5373

# %%
EA2200_1 = subset(EA2200, cor < 0)
length(EA2200_1$cor)/length(EA2200$cor)
1-length(EA2200_1$cor)/length(EA2200$cor)
# Out:
# [1] 0.3300493
# [1] 0.6699507

# %%
EA2200_2 = EA2200[,c(1,3)]
EA2200_net = graph_from_edgelist(as.matrix(EA2200_2), directed = FALSE)
length(V(EA2200_net))
length(E(EA2200_net))
# average degree
mean(degree(EA2200_net))
# average betweenness
mean(betweenness(EA2200_net))
# clustering coefficient
transitivity(EA2200_net)
# modularity
EA2200_m = cluster_fast_greedy(EA2200_net)
modularity(EA2200_net, membership(EA2200_m))
# Out:
# [1] 150
# [1] 812
# [1] 10.82667
# [1] 114.8733
# [1] 0.5011564
# [1] 0.2598537

# %%
EA2300 = read.table(file = "Network/Fastspar/EA2300.txt", header =T)
head(EA2300)
# Out:
#   ID2                              treat2 ID1
# 1 824010500d0911bcd70f690960a8e859 EA2300 aa3c7749c78163f5be32feea6e2f1eba
# 2 9ec8e79f52b80a2ccc6ea2606c005ea5 EA2300 65bb0fbfd950451626807f4dd07771fe
# 3 aeffc44cf27980934d2cfa4922f7f564 EA2300 65bb0fbfd950451626807f4dd07771fe
# 4 81540b57bab4bc652bccc5cfa73b787b EA2300 65bb0fbfd950451626807f4dd07771fe
# 5 36e1598c97b3f20cf1e2daaedf8ac00c EA2300 65bb0fbfd950451626807f4dd07771fe
# 6 6baabed181b2ad35ffe9cbcc8562019e EA2300 65bb0fbfd950451626807f4dd07771fe
#   treat1 pval  cor     abscor
# 1 EA2300 0.001 -0.4058 0.4058
# 2 EA2300 0.001  0.4285 0.4285
# 3 EA2300 0.001  0.4884 0.4884
# 4 EA2300 0.001  0.5549 0.5549
# 5 EA2300 0.001  0.4319 0.4319
# 6 EA2300 0.001  0.4712 0.4712

# %%
EA2300_1 = subset(EA2300, cor < 0)
length(EA2300_1$cor)/length(EA2300$cor)
1-length(EA2300_1$cor)/length(EA2300$cor)
# Out:
# [1] 0.2943604
# [1] 0.7056396

# %%
EA2300_2 = EA2300[,c(1,3)]
EA2300_net = graph_from_edgelist(as.matrix(EA2300_2), directed = FALSE)
length(V(EA2300_net))
length(E(EA2300_net))
# average degree
mean(degree(EA2300_net))
# average betweenness
mean(betweenness(EA2300_net))
# clustering coefficient
transitivity(EA2300_net)
# modularity
EA2300_m = cluster_fast_greedy(EA2300_net)
modularity(EA2300_net, membership(EA2300_m))
# Out:
# [1] 141
# [1] 727
# [1] 10.31206
# [1] 108.2837
# [1] 0.4689252
# [1] 0.2662465

# %%
EA2400 = read.table(file = "Network/Fastspar/EA2400.txt", header =T)
head(EA2400)
# Out:
#   ID2                              treat2 ID1
# 1 824010500d0911bcd70f690960a8e859 EA2400 aa3c7749c78163f5be32feea6e2f1eba
# 2 04c53787739acaf3388248ad5b8b7c76 EA2400 17a6627b3e512658dd3424fedb302bb7
# 3 fb435faf18ac9b76692687b973a617cc EA2400 9ec8e79f52b80a2ccc6ea2606c005ea5
# 4 e3a8c711006750f5a91f7aba36569eb8 EA2400 9ec8e79f52b80a2ccc6ea2606c005ea5
# 5 3f06c7bc691bbb0332b9ceac51b62666 EA2400 9ec8e79f52b80a2ccc6ea2606c005ea5
# 6 5d1bbbf631697587d4aa346be53dc1d7 EA2400 9ec8e79f52b80a2ccc6ea2606c005ea5
#   treat1 pval  cor     abscor
# 1 EA2400 0.001 -0.4058 0.4058
# 2 EA2400 0.001  0.4309 0.4309
# 3 EA2400 0.001  0.4706 0.4706
# 4 EA2400 0.001 -0.4300 0.4300
# 5 EA2400 0.001  0.4965 0.4965
# 6 EA2400 0.001  0.4452 0.4452

# %%
EA2400_1 = subset(EA2400, cor < 0)
length(EA2400_1$cor)/length(EA2400$cor)
1-length(EA2400_1$cor)/length(EA2400$cor)
# Out:
# [1] 0.2530303
# [1] 0.7469697

# %%
EA2400_2 = EA2400[,c(1,3)]
EA2400_net = graph_from_edgelist(as.matrix(EA2400_2), directed = FALSE)
length(V(EA2400_net))
length(E(EA2400_net))
# average degree
mean(degree(EA2400_net))
# average betweenness
mean(betweenness(EA2400_net))
# clustering coefficient
transitivity(EA2400_net)
# modularity
EA2400_m = cluster_fast_greedy(EA2400_net)
modularity(EA2400_net, membership(EA2400_m))
# Out:
# [1] 137
# [1] 660
# [1] 9.635036
# [1] 105.6715
# [1] 0.4766144
# [1] 0.2841816

# %%
fastspar_topology = read.table(file = "Network/Fastspar/fastspar_topology.txt")
head(fastspar_topology)
# Out:
#        host elevation negative  positive  node edge degree   betweenness
# AL600  AL    600      0.2163522 0.7836478 128   795 12.42188  75.50000
# AL700  AL    700      0.2132170 0.7867830 130   802 12.33846  67.40769
# AL800  AL    800      0.2485549 0.7514451 139   865 12.44604  76.12950
# AL900  AL    900      0.2993865 0.7006135 125   815 13.04000  77.92800
# AL1000 AL   1000      0.3716679 0.6283321 172  1313 15.26744 107.94767
# AL1100 AL   1100      0.3743456 0.6256544 161  1146 14.23602  92.86335
#        cluster_coeff modularity
# AL600  0.4840312     0.2029089
# AL700  0.4841088     0.2014672
# AL800  0.4659297     0.2132079
# AL900  0.5099651     0.1983989
# AL1000 0.4909125     0.2090188
# AL1100 0.4834406     0.1977129

# %%
fastspar_topology$PN = fastspar_topology$positive/fastspar_topology$negative
head(fastspar_topology)
# Out:
#        host elevation negative  positive  node edge degree   betweenness
# AL600  AL    600      0.2163522 0.7836478 128   795 12.42188  75.50000
# AL700  AL    700      0.2132170 0.7867830 130   802 12.33846  67.40769
# AL800  AL    800      0.2485549 0.7514451 139   865 12.44604  76.12950
# AL900  AL    900      0.2993865 0.7006135 125   815 13.04000  77.92800
# AL1000 AL   1000      0.3716679 0.6283321 172  1313 15.26744 107.94767
# AL1100 AL   1100      0.3743456 0.6256544 161  1146 14.23602  92.86335
#        cluster_coeff modularity PN
# AL600  0.4840312     0.2029089  3.622093
# AL700  0.4841088     0.2014672  3.690058
# AL800  0.4659297     0.2132079  3.023256
# AL900  0.5099651     0.1983989  2.340164
# AL1000 0.4909125     0.2090188  1.690574
# AL1100 0.4834406     0.1977129  1.671329

# %%
AL_fastspar_topology = subset(fastspar_topology, host == "AL")
EA_fastspar_topology = subset(fastspar_topology, host == "EA")

# %%
fastspar_topology1 = read.table(file = "Network/Fastspar/fastspar_topology1.txt", header =T )
head(fastspar_topology1)
# Out:
#        host elevation AL_negative AL_positive AL_node AL_edge AL_degree
# AL600  AL    600      0.2163522   0.7836478   128      795    12.42188
# AL700  AL    700      0.2132170   0.7867830   130      802    12.33846
# AL800  AL    800      0.2485549   0.7514451   139      865    12.44604
# AL900  AL    900      0.2993865   0.7006135   125      815    13.04000
# AL1000 AL   1000      0.3716679   0.6283321   172     1313    15.26744
# AL1100 AL   1100      0.3743456   0.6256544   161     1146    14.23602
#        AL_betweenness AL_cluster_coeff AL_modularity AL_PN    EA_negative
# AL600   75.50000      0.4840312        0.2029089     3.622093 0.3211382
# AL700   67.40769      0.4841088        0.2014672     3.690058 0.2563510
# AL800   76.12950      0.4659297        0.2132079     3.023256 0.1291727
# AL900   77.92800      0.5099651        0.1983989     2.340164 0.3134615
# AL1000 107.94767      0.4909125        0.2090188     1.690574 0.3196078
# ...

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "node")
# Out:
# $BestFitM2
#        AIC      BIC  model       formula
# 2 159.2539 163.0317 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model        formula
# 2 159.2539 163.0317  line3P  y = ax^2+bx+c
# 3 160.6162 163.4495   log2P    y=a*ln(x)+b
# 5 160.6820 163.5154 power2P      y = a*x^b
# 1 161.4212 164.2546  line2P       y = ax+b
# 4 161.4620 164.2953   exp2P y = a*exp(b*x)

# %%
summary(lm(node~elevation + I(elevation^2),data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = node ~ elevation + I(elevation^2), data = AL_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.140  -4.308  -0.245   6.001  27.791
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     8.989e+01  2.545e+01   3.532  0.00277 **
# elevation       7.832e-02  3.684e-02   2.126  0.04940 *
# I(elevation^2) -2.401e-05  1.212e-05  -1.981  0.06506 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.12 on 16 degrees of freedom
# Multiple R-squared:  0.2402,	Adjusted R-squared:  0.1452
# F-statistic: 2.529 on 2 and 16 DF,  p-value: 0.1111

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "node")
# Out:
# $BestFitM2
#        AIC      BIC  model       formula
# 2 146.3739 150.1516 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model        formula
# 2 146.3739 150.1516  line3P  y = ax^2+bx+c
# 3 155.9064 158.7398   log2P    y=a*ln(x)+b
# 5 155.9615 158.7948 power2P      y = a*x^b
# 1 156.7892 159.6226  line2P       y = ax+b
# 4 156.8087 159.6420   exp2P y = a*exp(b*x)

# %%
summary(lm(node~elevation + I(elevation^2),data = EA_fastspar_topology))
# Out:
# Call:
# lm(formula = node ~ elevation + I(elevation^2), data = EA_fastspar_topology)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -25.6554  -4.2797   0.7099   6.0416  15.6331
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     8.258e+01  1.813e+01   4.554 0.000325 ***
# elevation       1.029e-01  2.625e-02   3.920 0.001222 **
# I(elevation^2) -3.317e-05  8.636e-06  -3.841 0.001442 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 10.06 on 16 degrees of freedom
# Multiple R-squared:  0.4903,	Adjusted R-squared:  0.4266
# F-statistic: 7.697 on 2 and 16 DF,  p-value: 0.004552

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_node)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_node), color = "#1e90ff") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#ff8c00", se = FALSE) +
  geom_vline(aes(xintercept = 1550), colour = "#ff8c00", linetype = "dashed", size =1) +
  labs(x = "Elevation(m)" , y = "Node" ) +   
  theme_bw()
# Out:
# plot without title

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "edge")
# Out:
# $BestFitM2
#        AIC     BIC  model       formula
# 2 248.3183 252.096 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model        formula
# 2 248.3183 252.0960  line3P  y = ax^2+bx+c
# 1 249.6894 252.5227  line2P       y = ax+b
# 4 250.0104 252.8437   exp2P y = a*exp(b*x)
# 3 251.3678 254.2011   log2P    y=a*ln(x)+b
# 5 251.6518 254.4851 power2P      y = a*x^b

# %%
summary(lm(edge~elevation + I(elevation^2),data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = edge ~ elevation + I(elevation^2), data = AL_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -254.87  -66.42  -27.91   30.43  381.26
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     6.286e+02  2.652e+02   2.370   0.0307 *
# elevation       5.257e-01  3.839e-01   1.370   0.1898
# I(elevation^2) -2.226e-04  1.263e-04  -1.762   0.0971 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 147.1 on 16 degrees of freedom
# Multiple R-squared:  0.3449,	Adjusted R-squared:  0.263
# F-statistic: 4.211 on 2 and 16 DF,  p-value: 0.03393

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "edge")
# Out:
# $BestFitM2
#        AIC      BIC  model       formula
# 2 242.4671 246.2449 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model        formula
# 2 242.4671 246.2449  line3P  y = ax^2+bx+c
# 1 249.4927 252.3260  line2P       y = ax+b
# 4 249.9023 252.7356   exp2P y = a*exp(b*x)
# 3 251.4925 254.3259   log2P    y=a*ln(x)+b
# 5 251.7360 254.5693 power2P      y = a*x^b

# %%
summary(lm(edge~elevation + I(elevation^2),data = EA_fastspar_topology))
# Out:
# Call:
# lm(formula = edge ~ elevation + I(elevation^2), data = EA_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -269.69  -48.67   27.08   49.42  211.49
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4.753e+02  2.274e+02   2.090  0.05290 .
# elevation       8.744e-01  3.291e-01   2.657  0.01722 *
# I(elevation^2) -3.377e-04  1.083e-04  -3.119  0.00661 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 126.1 on 16 degrees of freedom
# Multiple R-squared:  0.5096,	Adjusted R-squared:  0.4483
# F-statistic: 8.314 on 2 and 16 DF,  p-value: 0.003344

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_edge)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_edge), color = "#1e90ff") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#ff8c00", se = FALSE) +
  geom_vline(aes(xintercept = 1290), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_vline(aes(xintercept = 1180), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,aes(elevation,AL_edge)) +
  labs(x = "Elevation(m)" , y = "Edge" ) +   
  theme_bw()
# Out:
# plot without title

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "degree")
# Out:
# $BestFitM2
#        AIC      BIC  model  formula
# 1 59.35545 62.18877 line2P y = ax+b
#
# $AllModel
#        AIC      BIC   model        formula
# 1 59.35545 62.18877  line2P       y = ax+b
# 2 59.51124 63.28899  line3P  y = ax^2+bx+c
# 4 60.25905 63.09237   exp2P y = a*exp(b*x)
# 3 63.95071 66.78403   log2P    y=a*ln(x)+b
# 5 65.25845 68.09177 power2P      y = a*x^b

# %%
summary(lm(degree~elevation,data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = degree ~ elevation, data = AL_fastspar_topology)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.37729 -0.62557 -0.03131  0.58753  2.44659
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.2612511  0.6966855  21.906 6.73e-14 ***
# elevation   -0.0024404  0.0004363  -5.594 3.23e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.042 on 17 degrees of freedom
# Multiple R-squared:  0.648,	Adjusted R-squared:  0.6272
# F-statistic: 31.29 on 1 and 17 DF,  p-value: 3.228e-05

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "degree")
# Out:
# $BestFitM2
#       AIC      BIC  model       formula
# 2 59.6725 63.45026 line3P y = ax^2+bx+c
#
# $AllModel
#        AIC      BIC   model        formula
# 2 59.67250 63.45026  line3P  y = ax^2+bx+c
# 1 62.08494 64.91826  line2P       y = ax+b
# 4 62.90393 65.73725   exp2P y = a*exp(b*x)
# 3 66.03172 68.86504   log2P    y=a*ln(x)+b
# 5 66.84075 69.67407 power2P      y = a*x^b

# %%
summary(lm(degree~elevation + I(elevation^2),data = EA_fastspar_topology))
# Out:
# Call:
# lm(formula = degree ~ elevation + I(elevation^2), data = EA_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5826 -0.4724  0.0713  0.5298  2.1917
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     1.178e+01  1.852e+00   6.360 9.46e-06 ***
# elevation       3.287e-03  2.680e-03   1.226   0.2378
# I(elevation^2) -1.804e-06  8.819e-07  -2.045   0.0577 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.027 on 16 degrees of freedom
# Multiple R-squared:  0.6408,	Adjusted R-squared:  0.5959
# F-statistic: 14.27 on 2 and 16 DF,  p-value: 0.0002771

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_degree)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_degree), color = "#1e90ff") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#ff8c00", se = FALSE) +
  geom_vline(aes(xintercept = 911), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_smooth(method = "lm",  color = "#1e90ff", se = FALSE, aes(elevation,AL_degree)) +
  labs(x = "Elevation(m)" , y = "Degree" ) +   
  theme_bw()
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "betweenness")
# Out:
# $BestFitM2
#        AIC     BIC   model   formula
# 5 142.4756 145.309 power2P y = a*x^b
#
# $AllModel
#        AIC      BIC   model        formula
# 5 142.4756 145.3090 power2P      y = a*x^b
# 3 142.6063 145.4396   log2P    y=a*ln(x)+b
# 1 142.8969 145.7302  line2P       y = ax+b
# 4 143.3484 146.1817   exp2P y = a*exp(b*x)
# 2 144.4889 148.2667  line3P  y = ax^2+bx+c

# %%
summary(lm(betweenness~elevation,data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = betweenness ~ elevation, data = AL_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.929  -4.257  -2.415   2.710  24.326
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 63.066546   6.277909  10.046 1.45e-08 ***
# elevation    0.020555   0.003931   5.229 6.81e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.386 on 17 degrees of freedom
# Multiple R-squared:  0.6166,	Adjusted R-squared:  0.594
# F-statistic: 27.34 on 1 and 17 DF,  p-value: 6.812e-05

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "betweenness")
# Out:
# $BestFitM2
#        AIC      BIC   model   formula
# 5 139.6763 142.5097 power2P y = a*x^b
#
# $AllModel
#        AIC      BIC   model        formula
# 5 139.6763 142.5097 power2P      y = a*x^b
# 3 139.8218 142.6551   log2P    y=a*ln(x)+b
# 1 140.3987 143.2320  line2P       y = ax+b
# 2 140.8498 144.6275  line3P  y = ax^2+bx+c
# 4 141.0795 143.9128   exp2P y = a*exp(b*x)

# %%
summary(lm(betweenness~elevation,data = EA_fastspar_topology))
# Out:
# Call:
# lm(formula = betweenness ~ elevation, data = EA_fastspar_topology)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.852  -5.538  -0.429   7.123  14.457
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 71.427545   5.878464  12.151 8.31e-10 ***
# elevation    0.019058   0.003681   5.177 7.58e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.789 on 17 degrees of freedom
# Multiple R-squared:  0.6119,	Adjusted R-squared:  0.5891
# F-statistic:  26.8 on 1 and 17 DF,  p-value: 7.579e-05

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_betweenness)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_betweenness), color = "#1e90ff") +
  geom_smooth(method = "lm", color = "#ff8c00", se = FALSE) +
  geom_smooth(method = "lm",  color = "#1e90ff", se = FALSE, aes(elevation,AL_betweenness)) +
  labs(x = "Elevation(m)" , y = "betweenness" ) +   
  theme_bw()
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "cluster_coeff")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -99.93773 -96.15997 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -99.93773 -96.15997  line3P  y = ax^2+bx+c
# 1 -89.13608 -86.30277  line2P       y = ax+b
# 4 -89.11881 -86.28549   exp2P y = a*exp(b*x)
# 3 -88.52564 -85.69233   log2P    y=a*ln(x)+b
# 5 -88.52358 -85.69026 power2P      y = a*x^b

# %%
summary(lm(cluster_coeff ~ elevation + I(elevation^2), data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = cluster_coeff ~ elevation + I(elevation^2), data = AL_fastspar_topology)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.025252 -0.006577  0.001635  0.009093  0.028448
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4.037e-01  2.776e-02  14.541 1.22e-10 ***
# elevation       1.486e-04  4.018e-05   3.698  0.00195 **
# I(elevation^2) -5.186e-08  1.322e-08  -3.922  0.00121 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0154 on 16 degrees of freedom
# Multiple R-squared:  0.5086,	Adjusted R-squared:  0.4471
# F-statistic: 8.279 on 2 and 16 DF,  p-value: 0.003402

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "cluster_coeff")
# Out:
# $BestFitM2
#         AIC      BIC  model       formula
# 2 -87.45345 -83.6757 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -87.45345 -83.67570  line3P  y = ax^2+bx+c
# 3 -75.93181 -73.09849   log2P    y=a*ln(x)+b
# 5 -75.86852 -73.03520 power2P      y = a*x^b
# 1 -74.70920 -71.87588  line2P       y = ax+b
# 4 -74.68070 -71.84738   exp2P y = a*exp(b*x)

# %%
summary(lm(cluster_coeff ~ elevation + I(elevation^2), data = EA_fastspar_topology))
# Out:
# Call:
# lm(formula = cluster_coeff ~ elevation + I(elevation^2), data = EA_fastspar_topology)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03546 -0.01287  0.00498  0.01164  0.03258
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.274e-01  3.856e-02   8.490 2.54e-07 ***
# elevation       2.493e-04  5.581e-05   4.467 0.000389 ***
# I(elevation^2) -7.954e-08  1.836e-08  -4.332 0.000515 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02139 on 16 degrees of freedom
# Multiple R-squared:  0.5579,	Adjusted R-squared:  0.5026
# F-statistic: 10.09 on 2 and 16 DF,  p-value: 0.00146

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_cluster_coeff)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_cluster_coeff), color = "#1e90ff") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#ff8c00", se = FALSE) +
  geom_vline(aes(xintercept = 1570), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_vline(aes(xintercept = 1430), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,aes(elevation,AL_cluster_coeff)) +
  labs(x = "Elevation(m)" , y = "Cluster coefficient" ) +   
  theme_bw()
# Out:
# plot without title

# %%
bestFitM2(data =AL_fastspar_topology , x = "elevation", y = "modularity")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -97.92271 -94.14495 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -97.92271 -94.14495  line3P  y = ax^2+bx+c
# 4 -95.27517 -92.44185   exp2P y = a*exp(b*x)
# 1 -93.77898 -90.94566  line2P       y = ax+b
# 5 -89.38537 -86.55205 power2P      y = a*x^b
# 3 -87.61323 -84.77992   log2P    y=a*ln(x)+b

# %%
summary(lm(modularity ~ elevation + I(elevation^2), data = AL_fastspar_topology))
# Out:
# Call:
# lm(formula = modularity ~ elevation + I(elevation^2), data = AL_fastspar_topology)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.026329 -0.009056 -0.001260  0.007707  0.033292
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     2.214e-01  2.927e-02   7.564 1.14e-06 ***
# elevation      -5.519e-05  4.237e-05  -1.303   0.2111
# I(elevation^2)  3.445e-08  1.394e-08   2.471   0.0251 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01624 on 16 degrees of freedom
# Multiple R-squared:  0.7786,	Adjusted R-squared:  0.7509
# F-statistic: 28.13 on 2 and 16 DF,  p-value: 5.773e-06

# %%
bestFitM2(data =EA_fastspar_topology , x = "elevation", y = "modularity")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -99.48113 -95.70338 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -99.48113 -95.70338  line3P  y = ax^2+bx+c
# 4 -85.99393 -83.16061   exp2P y = a*exp(b*x)
# 1 -84.56532 -81.73201  line2P       y = ax+b
# 5 -80.63783 -77.80452 power2P      y = a*x^b
# 3 -79.55873 -76.72541   log2P    y=a*ln(x)+b

# %%
summary(lm(modularity ~ elevation + I(elevation^2), data =EA_fastspar_topology))
# Out:
# Call:
# lm(formula = modularity ~ elevation + I(elevation^2), data = EA_fastspar_topology)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.024861 -0.009481 -0.003084  0.009243  0.036511
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     2.853e-01  2.810e-02  10.153 2.22e-08 ***
# elevation      -1.510e-04  4.067e-05  -3.714 0.001887 **
# I(elevation^2)  6.413e-08  1.338e-08   4.793 0.000199 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01558 on 16 degrees of freedom
# Multiple R-squared:  0.7978,	Adjusted R-squared:  0.7726
# F-statistic: 31.57 on 2 and 16 DF,  p-value: 2.791e-06

# %%
ggplot(data = fastspar_topology1, aes(x = elevation, y = EA_modularity)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_modularity), color = "#1e90ff") +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#ff8c00", se = FALSE) +
  geom_vline(aes(xintercept = 1180), colour = "#ff8c00", linetype = "dashed", size =1) +
  geom_vline(aes(xintercept = 810), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,aes(elevation,AL_modularity)) +
  labs(x = "Elevation(m)" , y = "Modularity" ) +   
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# #### sparCC correlation was convert to Cohesion for quantifying the connectivity of microbial communities according to Herren et al., 2017,  the ISME Journal

# %%
fastspar_cohension = read.table(file = "Network/Fastspar/fastspar_cohension.txt", header = T)
head(fastspar_cohension)
# Out:
#        host elevation positive_cohension negative_cohension
# AL600  AL    600      0.1707288          -0.12458137
# AL700  AL    700      0.1910372          -0.10599237
# AL800  AL    800      0.2193746          -0.14375422
# AL900  AL    900      0.1345403          -0.07241150
# AL1000 AL   1000      0.2008537          -0.13613613
# AL1100 AL   1100      0.1958574          -0.09811214

# %%
fastspar_cohension$absNC = abs(fastspar_cohension$negative_cohension)
fastspar_cohension$total = fastspar_cohension$positive_cohension + fastspar_cohension$absNC
fastspar_cohension$PC_NC = fastspar_cohension$positive_cohension/fastspar_cohension$absNC

head(fastspar_cohension)
# Out:
#        host elevation positive_cohension negative_cohension absNC
# AL600  AL    600      0.1707288          -0.12458137        0.12458137
# AL700  AL    700      0.1910372          -0.10599237        0.10599237
# AL800  AL    800      0.2193746          -0.14375422        0.14375422
# AL900  AL    900      0.1345403          -0.07241150        0.07241150
# AL1000 AL   1000      0.2008537          -0.13613613        0.13613613
# AL1100 AL   1100      0.1958574          -0.09811214        0.09811214
#        total     PC_NC
# AL600  0.2953102 1.370420
# AL700  0.2970296 1.802368
# AL800  0.3631288 1.526039
# AL900  0.2069518 1.857996
# AL1000 0.3369898 1.475389
# AL1100 0.2939695 1.996261

# %%
AL_fastspar_cohension = subset(fastspar_cohension, host == "AL")
EA_fastspar_cohension = subset(fastspar_cohension, host == "EA")

# %%
bestFitM2(data =AL_fastspar_cohension , x = "elevation", y = "positive_cohension")
# Out:
# $BestFitM2
#         AIC       BIC model        formula
# 4 -79.66315 -76.82983 exp2P y = a*exp(b*x)
#
# $AllModel
#         AIC       BIC   model        formula
# 4 -79.66315 -76.82983   exp2P y = a*exp(b*x)
# 1 -79.34146 -76.50814  line2P       y = ax+b
# 2 -79.08236 -75.30461  line3P  y = ax^2+bx+c
# 5 -78.04642 -75.21311 power2P      y = a*x^b
# 3 -77.64780 -74.81449   log2P    y=a*ln(x)+b

# %%
summary(lm(positive_cohension~elevation, data = AL_fastspar_cohension))
# Out:
# Call:
# lm(formula = positive_cohension ~ elevation, data = AL_fastspar_cohension)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.043282 -0.023858  0.004363  0.019792  0.044891
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.478e-01  1.811e-02   8.160 2.78e-07 ***
# elevation   3.339e-05  1.134e-05   2.944  0.00907 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02707 on 17 degrees of freedom
# Multiple R-squared:  0.3377,	Adjusted R-squared:  0.2987
# F-statistic: 8.668 on 1 and 17 DF,  p-value: 0.009071

# %%
bestFitM2(data =EA_fastspar_cohension , x = "elevation", y = "positive_cohension")
# Out:
# $BestFitM2
#         AIC      BIC model        formula
# 4 -67.50272 -64.6694 exp2P y = a*exp(b*x)
#
# $AllModel
#         AIC       BIC   model        formula
# 4 -67.50272 -64.66940   exp2P y = a*exp(b*x)
# 1 -67.45575 -64.62243  line2P       y = ax+b
# 5 -67.18399 -64.35067 power2P      y = a*x^b
# 3 -67.14935 -64.31603   log2P    y=a*ln(x)+b
# 2 -66.05867 -62.28091  line3P  y = ax^2+bx+c

# %%
summary(lm(positive_cohension~elevation, data = EA_fastspar_cohension))
# Out:
# Call:
# lm(formula = positive_cohension ~ elevation, data = EA_fastspar_cohension)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.063490 -0.024905  0.003622  0.018046  0.088469
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.615e-01  2.476e-02   6.522 5.22e-06 ***
# elevation   1.854e-05  1.550e-05   1.196    0.248
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03702 on 17 degrees of freedom
# Multiple R-squared:  0.07761,	Adjusted R-squared:  0.02335
# F-statistic:  1.43 on 1 and 17 DF,  p-value: 0.2481

# %%
fastspar_cohension1 = read.table(file = "Network/Fastspar/fastspar_cohension1.txt", header =T)
head(fastspar_cohension1)
# Out:
#   elevation AL_positive_cohension AL_absNC   AL_total  AL_PC_NC
# 1  600      0.1707288             0.12458137 0.2953102 1.370420
# 2  700      0.1910372             0.10599237 0.2970296 1.802368
# 3  800      0.2193746             0.14375422 0.3631288 1.526039
# 4  900      0.1345403             0.07241150 0.2069518 1.857996
# 5 1000      0.2008537             0.13613613 0.3369898 1.475389
# 6 1100      0.1958574             0.09811214 0.2939695 1.996261
#   EA_positive_cohension EA_absNC  EA_total  EA_PC_NC
# 1 0.1470206             0.1158196 0.2628402 1.269393
# 2 0.1502243             0.1146443 0.2648687 1.310351
# 3 0.2647779             0.1683243 0.4331022 1.573022
# 4 0.2118960             0.1187673 0.3306633 1.784127
# 5 0.1934963             0.1162552 0.3097515 1.664410
# 6 0.1985814             0.1164312 0.3150126 1.705568

# %%
ggplot(data = fastspar_cohension1, aes(x = elevation, y = EA_positive_cohension)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_positive_cohension), color = "#1e90ff", se = FALSE) +
  geom_smooth(method = "lm", color = "#1e90ff", se = FALSE, aes(elevation,AL_positive_cohension)) +
  labs(x = "Elevation(m)" , y = "Positive cohension" ) +
  theme_bw()
# Out:
# Warning message:
# “Ignoring unknown parameters: se”
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
bestFitM2(data =AL_fastspar_cohension , x = "elevation", y = "absNC")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -82.27809 -78.50034 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -82.27809 -78.50034  line3P  y = ax^2+bx+c
# 4 -82.15443 -79.32112   exp2P y = a*exp(b*x)
# 1 -81.58745 -78.75413  line2P       y = ax+b
# 5 -80.20894 -77.37563 power2P      y = a*x^b
# 3 -79.49746 -76.66414   log2P    y=a*ln(x)+b

# %%
summary(lm(absNC ~ elevation + I(elevation^2), data = AL_fastspar_cohension))
# Out:
# Call:
# lm(formula = absNC ~ elevation + I(elevation^2), data = AL_fastspar_cohension)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.037509 -0.018749 -0.004011  0.020835  0.034380
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     1.440e-01  4.418e-02   3.258  0.00493 **
# elevation      -6.738e-05  6.395e-05  -1.054  0.30776
# I(elevation^2)  3.283e-08  2.104e-08   1.560  0.13828
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02451 on 16 degrees of freedom
# Multiple R-squared:  0.4207,	Adjusted R-squared:  0.3483
# F-statistic: 5.809 on 2 and 16 DF,  p-value: 0.01269

# %%
bestFitM2(data =EA_fastspar_cohension , x = "elevation", y = "absNC")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -81.85902 -78.08127 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -81.85902 -78.08127  line3P  y = ax^2+bx+c
# 4 -80.41149 -77.57817   exp2P y = a*exp(b*x)
# 1 -80.35334 -77.52003  line2P       y = ax+b
# 5 -79.92727 -77.09395 power2P      y = a*x^b
# 3 -79.90515 -77.07184   log2P    y=a*ln(x)+b

# %%
summary(lm(absNC ~ elevation + I(elevation^2), data = EA_fastspar_cohension))
# Out:
# Call:
# lm(formula = absNC ~ elevation + I(elevation^2), data = EA_fastspar_cohension)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.042871 -0.017561  0.003118  0.008735  0.048142
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     1.806e-01  4.467e-02   4.042 0.000945 ***
# elevation      -1.061e-04  6.466e-05  -1.641 0.120227
# I(elevation^2)  3.831e-08  2.128e-08   1.801 0.090650 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02478 on 16 degrees of freedom
# Multiple R-squared:  0.1983,	Adjusted R-squared:  0.09812
# F-statistic: 1.979 on 2 and 16 DF,  p-value: 0.1706

# %%
ggplot(data = fastspar_cohension1, aes(x = elevation, y = EA_absNC)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_absNC), color = "#1e90ff", se = FALSE) +
  geom_vline(aes(xintercept = 1030), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,aes(elevation,AL_absNC)) +
  labs(x = "Elevation(m)" , y = "|Negative cohension|" ) +   
  theme_bw()
# Out:
# Warning message:
# “Ignoring unknown parameters: se”
# plot without title

# %%
bestFitM2(data =AL_fastspar_cohension , x = "elevation", y = "total")
# Out:
# $BestFitM2
#         AIC       BIC model        formula
# 4 -56.23756 -53.40424 exp2P y = a*exp(b*x)
#
# $AllModel
#         AIC       BIC   model        formula
# 4 -56.23756 -53.40424   exp2P y = a*exp(b*x)
# 2 -56.16471 -52.38696  line3P  y = ax^2+bx+c
# 1 -55.78032 -52.94701  line2P       y = ax+b
# 5 -54.28909 -51.45577 power2P      y = a*x^b
# 3 -53.72559 -50.89227   log2P    y=a*ln(x)+b

# %%
summary(lm(total ~ elevation + I(elevation^2), data = AL_fastspar_cohension))
# Out:
# Call:
# lm(formula = total ~ elevation + I(elevation^2), data = AL_fastspar_cohension)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.082493 -0.037153  0.003351  0.038837  0.072179
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.470e-01  8.785e-02   3.951  0.00114 **
# elevation      -1.191e-04  1.272e-04  -0.936  0.36297
# I(elevation^2)  6.119e-08  4.183e-08   1.463  0.16293
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04873 on 16 degrees of freedom
# Multiple R-squared:  0.4311,	Adjusted R-squared:   0.36
# F-statistic: 6.063 on 2 and 16 DF,  p-value: 0.01097

# %%
bestFitM2(data =EA_fastspar_cohension , x = "elevation", y = "total")
# Out:
# $BestFitM2
#         AIC       BIC model        formula
# 4 -48.70931 -45.87599 exp2P y = a*exp(b*x)
#
# $AllModel
#         AIC       BIC   model        formula
# 4 -48.70931 -45.87599   exp2P y = a*exp(b*x)
# 1 -48.64591 -45.81259  line2P       y = ax+b
# 2 -48.26647 -44.48871  line3P  y = ax^2+bx+c
# 5 -48.23203 -45.39871 power2P      y = a*x^b
# 3 -48.19116 -45.35784   log2P    y=a*ln(x)+b

# %%
summary(lm(total ~ elevation , data = EA_fastspar_cohension))
# Out:
# Call:
# lm(formula = total ~ elevation, data = EA_fastspar_cohension)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.09871 -0.03531  0.01211  0.02222  0.14389
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.674e-01  4.062e-02   6.582 4.66e-06 ***
# elevation   2.733e-05  2.544e-05   1.074    0.298
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06073 on 17 degrees of freedom
# Multiple R-squared:  0.06358,	Adjusted R-squared:  0.0085
# F-statistic: 1.154 on 1 and 17 DF,  p-value: 0.2977

# %%
ggplot(data = fastspar_cohension1, aes(x = elevation, y = EA_total)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_total), color = "#1e90ff") +
  geom_vline(aes(xintercept = 973), colour = "#1e90ff", linetype = "dashed", size =1) +
  geom_smooth(method = "gam", formula = y ~ x + I(x^2), color = "#1e90ff", se = FALSE,aes(elevation,AL_total)) +
  labs(x = "Elevation(m)" , y = "Total cohension" ) +   
  theme_bw()
# Out:
# plot without title

# %%
bestFitM2(data =AL_fastspar_cohension , x = "elevation", y = "PC_NC")
# Out:
# $BestFitM2
#          AIC      BIC  model  formula
# 1 -0.9290832 1.904234 line2P y = ax+b
#
# $AllModel
#            AIC      BIC   model        formula
# 1 -0.929083236 1.904234  line2P       y = ax+b
# 4 -0.854490813 1.978826   exp2P y = a*exp(b*x)
# 2 -0.424104170 3.353652  line3P  y = ax^2+bx+c
# 3 -0.074192542 2.759124   log2P    y=a*ln(x)+b
# 5  0.001131793 2.834449 power2P      y = a*x^b

# %%
summary(lm(PC_NC~elevation, data = AL_fastspar_cohension))
# Out:
# Call:
# lm(formula = PC_NC ~ elevation, data = AL_fastspar_cohension)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.34884 -0.14866 -0.01773  0.10418  0.52520
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.798e+00  1.426e-01  12.612 4.68e-10 ***
# elevation   -1.315e-04  8.929e-05  -1.473    0.159
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2132 on 17 degrees of freedom
# Multiple R-squared:  0.1132,	Adjusted R-squared:  0.06107
# F-statistic: 2.171 on 1 and 17 DF,  p-value: 0.1589

# %%
bestFitM2(data =EA_fastspar_cohension , x = "elevation", y = "PC_NC")
# Out:
# $BestFitM2
#         AIC       BIC  model       formula
# 2 -7.597877 -3.820121 line3P y = ax^2+bx+c
#
# $AllModel
#         AIC       BIC   model        formula
# 2 -7.597877 -3.820121  line3P  y = ax^2+bx+c
# 3 -6.061789 -3.228472   log2P    y=a*ln(x)+b
# 5 -5.975581 -3.142264 power2P      y = a*x^b
# 1 -5.176896 -2.343579  line2P       y = ax+b
# 4 -5.142828 -2.309511   exp2P y = a*exp(b*x)

# %%
summary(lm(PC_NC~elevation + I(elevation^2), data = EA_fastspar_cohension))
# Out:
# Call:
# lm(formula = PC_NC ~ elevation + I(elevation^2), data = EA_fastspar_cohension)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.31724 -0.12086  0.05495  0.09301  0.23708
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     9.058e-01  3.153e-01   2.872   0.0111 *
# elevation       9.892e-04  4.564e-04   2.167   0.0456 *
# I(elevation^2) -3.075e-07  1.502e-07  -2.047   0.0574 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1749 on 16 degrees of freedom
# Multiple R-squared:  0.239,	Adjusted R-squared:  0.1439
# F-statistic: 2.512 on 2 and 16 DF,  p-value: 0.1125

# %%
ggplot(data = fastspar_cohension1, aes(x = elevation, y = EA_PC_NC)) +
  geom_point(color = "#ff8c00") +
  geom_point(aes(x = elevation, y = AL_PC_NC), color = "#1e90ff") +
  labs(x = "Elevation(m)" , y = "Positive/Negative cohension" ) +   
  theme_bw()
# Out:
# plot without title
